# %% [markdown]
# # Aggregation examples
#
# Working through the [https://www.elastic.co/guide/en/elasticsearch/guide/current/aggregations.html](Aggregations) chapter of *[https://www.elastic.co/guide/en/elasticsearch/guide/current/index.html](ElasticSearch: The Definitive Guide)*

# %%
import elasticsearch
from elasticsearch import helpers
import json

def p(doc, max_lines=25):
    lines = json.dumps(doc, indent=2, sort_keys=True).split('\n')
    if not max_lines or len(lines) <= max_lines:
        print('\n'.join(lines))
    else:
        print('\n'.join(lines[:max_lines/2]) + '\n...\n' + '\n'.join(lines[-max_lines/2:]))

# %%
es = elasticsearch.Elasticsearch(hosts=[{'host': 'localhost', 'port': 9200}])

# %%
helpers.bulk(client=es, index='cars', doc_type='transactions', actions=[
        { "price" : 10000, "color" : "red", "make" : "honda", "sold" : "2014-10-28" },
        { "price" : 20000, "color" : "red", "make" : "honda", "sold" : "2014-11-05" },
        { "price" : 30000, "color" : "green", "make" : "ford", "sold" : "2014-05-18" },
        { "price" : 15000, "color" : "blue", "make" : "toyota", "sold" : "2014-07-02" },
        { "price" : 12000, "color" : "green", "make" : "toyota", "sold" : "2014-08-19" },
        { "price" : 20000, "color" : "red", "make" : "honda", "sold" : "2014-11-05" },
        { "price" : 80000, "color" : "red", "make" : "bmw", "sold" : "2014-01-01" },
        { "price" : 25000, "color" : "blue", "make" : "ford", "sold" : "2014-02-12" },
    ])
# Out:
# (8, [])

# %%
p(es.search(index='cars', doc_type='transactions', body={
        "size": 0,
        "aggs": {
            "popular_colors": {
                "terms": {
                    "field": "color"
                }
            }
        }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "popular_colors": {
#       "buckets": [
#         {
#           "doc_count": 4,
#           "key": "red"
#         },
#         {
#           "doc_count": 2,
#           "key": "blue"
#         },
#         {
#           "doc_count": 2,
#           "key": "green"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     }
#   },
#   "hits": {
#     "hits": [],
#     "max_score": 0.0,
#     "total": 8
#   },
#   "timed_out": false,
#   "took": 4
# }

# %%
p(es.search(index='cars', doc_type='transactions', body={
        "size": 0,
        "aggs": {
            "popular_colors": {
                "terms": {
                    "field": "color"
                },
                "aggs": {
                    "avg_price": {
                            "avg": {
                                "field": "price"
                            }
                        }
                }
            }
        }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "popular_colors": {
#       "buckets": [
#         {
#           "avg_price": {
#             "value": 32500.0
#           },
#           "doc_count": 4,
#           "key": "red"
#         },
#         {
#           "avg_price": {
#             "value": 20000.0
#           },
#           "doc_count": 2,
#           "key": "blue"
#         },
#         {
#           "avg_price": {
#             "value": 21000.0
#           },
#           "doc_count": 2,
#           "key": "green"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     }
#   },
#   "hits": {
#     "hits": [],
#     "max_score": 0.0,
#     "total": 8
#   },
#   "timed_out": false,
#   "took": 20
# }

# %%
p(es.search(index='cars', doc_type='transactions', body={
        "size": 0,
        "aggs": {
            "popular_colors": {
                "terms": {
                    "field": "color"
                },
                "aggs": {
                    "avg_price": {
                            "avg": {
                                "field": "price"
                            }
                        },
                        "make": {
                            "terms": {
                                "field": "make"
                            }
                        }
                }
            }
        }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "popular_colors": {
#       "buckets": [
#         {
#           "avg_price": {
#             "value": 32500.0
#           },
#           "doc_count": 4,
#           "key": "red",
#           "make": {
#             "buckets": [
#               {
#                 "doc_count": 3,
#                 "key": "honda"
#               },
#               {
#                 "doc_count": 1,
#                 "key": "bmw"
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         },
#         {
#           "avg_price": {
#             "value": 20000.0
#           },
#           "doc_count": 2,
#           "key": "blue",
#           "make": {
#             "buckets": [
#               {
#                 "doc_count": 1,
#                 "key": "ford"
#               },
#               {
#                 "doc_count": 1,
#                 "key": "toyota"
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         },
#         {
#           "avg_price": {
#             "value": 21000.0
#           },
#           "doc_count": 2,
#           "key": "green",
#           "make": {
#             "buckets": [
#               {
#                 "doc_count": 1,
#                 "key": "ford"
#               },
#               {
#                 "doc_count": 1,
#                 "key": "toyota"
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     }
#   },
#   "hits": {
#     "hits": [],
#     "max_score": 0.0,
#     "total": 8
#   },
#   "timed_out": false,
#   "took": 11
# }

# %%
p(es.search(index='cars', doc_type='transactions', body={
        "size": 0,
        "aggs": {
            "popular_colors": {
                "terms": {
                    "field": "color"
                },
                "aggs": {
                    "avg_price": {
                            "avg": {
                                "field": "price"
                            }
                        },
                        "make": {
                            "terms": {
                                "field": "make"
                            },
                            "aggs": {
                                "min_price": { "min": { "field": "price" }},
                                "max_price": { "max": { "field": "price" }},
                            }
                        }
                }
            }
        }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "popular_colors": {
#       "buckets": [
#         {
#           "avg_price": {
#             "value": 32500.0
#           },
#           "doc_count": 4,
#           "key": "red",
#           "make": {
#             "buckets": [
#               {
#                 "doc_count": 3,
#                 "key": "honda",
#                 "max_price": {
#                   "value": 20000.0
#                 },
#                 "min_price": {
#                   "value": 10000.0
#                 }
#               },
#               {
#                 "doc_count": 1,
#                 "key": "bmw",
#                 "max_price": {
#                   "value": 80000.0
#                 },
#                 "min_price": {
#                   "value": 80000.0
#                 }
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         },
#         {
#           "avg_price": {
#             "value": 20000.0
#           },
#           "doc_count": 2,
#           "key": "blue",
#           "make": {
#             "buckets": [
#               {
#                 "doc_count": 1,
#                 "key": "ford",
#                 "max_price": {
#                   "value": 25000.0
#                 },
#                 "min_price": {
#                   "value": 25000.0
#                 }
#               },
#               {
#                 "doc_count": 1,
#                 "key": "toyota",
#                 "max_price": {
#                   "value": 15000.0
#                 },
#                 "min_price": {
#                   "value": 15000.0
#                 }
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         },
#         {
#           "avg_price": {
#             "value": 21000.0
#           },
#           "doc_count": 2,
#           "key": "green",
#           "make": {
#             "buckets": [
#               {
#                 "doc_count": 1,
#                 "key": "ford",
#                 "max_price": {
#                   "value": 30000.0
#                 },
#                 "min_price": {
#                   "value": 30000.0
#                 }
#               },
#               {
#                 "doc_count": 1,
#                 "key": "toyota",
#                 "max_price": {
#                   "value": 12000.0
#                 },
#                 "min_price": {
#                   "value": 12000.0
#                 }
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     }
#   },
#   "hits": {
#     "hits": [],
#     "max_score": 0.0,
#     "total": 8
#   },
#   "timed_out": false,
#   "took": 13
# }

# %%
es.search(index='cars', doc_type='transactions', body={
        "size": 0,
        "aggs": {
            "price": {
                "histogram": {
                    "field": "price",
                    "interval": 20000
                },
                "aggs": {
                    "revenue": {
                        "sum": {
                            "field": "price"
                        }
                    }
                }
            }
        }
    })
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'aggregations': {u'price': {u'buckets': [{u'doc_count': 3,
#      u'key': 0,
#      u'revenue': {u'value': 37000.0}},
#     {u'doc_count': 4, u'key': 20000, u'revenue': {u'value': 95000.0}},
#     {u'doc_count': 0, u'key': 40000, u'revenue': {u'value': 0.0}},
#     {u'doc_count': 0, u'key': 60000, u'revenue': {u'value': 0.0}},
#     {u'doc_count': 1, u'key': 80000, u'revenue': {u'value': 80000.0}}]}},
#  u'hits': {u'hits': [], u'max_score': 0.0, u'total': 8},
#  u'timed_out': False,
#  u'took': 8}

# %%
p(es.search(index='cars', doc_type='transactions', body={
        "size": 0,
        "aggs": {
            "makes": {
                "terms": {
                    "field": "make",
                    "size": 10
                },
                "aggs": {
                    "stats": {
                        "extended_stats": {
                            "field": "price"
                        }
                    }
                }
            }
        }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "makes": {
#       "buckets": [
#         {
#           "doc_count": 3,
#           "key": "honda",
#           "stats": {
#             "avg": 16666.666666666668,
#             "count": 3,
#             "max": 20000.0,
#             "min": 10000.0,
#             "std_deviation": 4714.045207910315,
#             "std_deviation_bounds": {
#               "lower": 7238.5762508460375,
#               "upper": 26094.757082487296
#             },
#             "sum": 50000.0,
#             "sum_of_squares": 900000000.0,
#             "variance": 22222222.22222221
#           }
#         },
#         {
#           "doc_count": 2,
#           "key": "ford",
#           "stats": {
#             "avg": 27500.0,
#             "count": 2,
#             "max": 30000.0,
#             "min": 25000.0,
#             "std_deviation": 2500.0,
#             "std_deviation_bounds": {
#               "lower": 22500.0,
#               "upper": 32500.0
#             },
#             "sum": 55000.0,
#             "sum_of_squares": 1525000000.0,
#             "variance": 6250000.0
#           }
#         },
#         {
#           "doc_count": 2,
#           "key": "toyota",
#           "stats": {
#             "avg": 13500.0,
#             "count": 2,
#             "max": 15000.0,
#             "min": 12000.0,
#             "std_deviation": 1500.0,
#             "std_deviation_bounds": {
#               "lower": 10500.0,
#               "upper": 16500.0
#             },
#             "sum": 27000.0,
#             "sum_of_squares": 369000000.0,
#             "variance": 2250000.0
#           }
#         },
#         {
#           "doc_count": 1,
#           "key": "bmw",
#           "stats": {
#             "avg": 80000.0,
#             "count": 1,
#             "max": 80000.0,
#             "min": 80000.0,
#             "std_deviation": 0.0,
#             "std_deviation_bounds": {
#               "lower": 80000.0,
#               "upper": 80000.0
#             },
#             "sum": 80000.0,
#             "sum_of_squares": 6400000000.0,
#             "variance": 0.0
#           }
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     }
#   },
#   "hits": {
#     "hits": [],
#     "max_score": 0.0,
#     "total": 8
#   },
#   "timed_out": false,
#   "took": 3
# }

# %%
p(es.search(index='cars', doc_type='transactions', body={
        "size": 0,
        "aggs": {
            "sales": {
                "date_histogram": {
                    "field": "sold",
                    "interval": "month",
                    "format": "yyyy-MM-dd",
                    "min_doc_count": 0,
                    "extended_bounds": {
                        "min": "2014-01-01",
                        "max": "2014-12-31"
                    }
                }
            }
        }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "sales": {
#       "buckets": [
#         {
#           "doc_count": 1,
#           "key": 1388534400000,
#           "key_as_string": "2014-01-01"
#         },
#         {
#           "doc_count": 1,
#           "key": 1391212800000,
#           "key_as_string": "2014-02-01"
#         },
#         {
#           "doc_count": 0,
#           "key": 1393632000000,
#           "key_as_string": "2014-03-01"
#         },
#         {
#           "doc_count": 0,
#           "key": 1396310400000,
#           "key_as_string": "2014-04-01"
#         },
#         {
#           "doc_count": 1,
#           "key": 1398902400000,
#           "key_as_string": "2014-05-01"
#         },
#         {
#           "doc_count": 0,
#           "key": 1401580800000,
#           "key_as_string": "2014-06-01"
#         },
#         {
#           "doc_count": 1,
#           "key": 1404172800000,
#           "key_as_string": "2014-07-01"
#         },
#         {
#           "doc_count": 1,
#           "key": 1406851200000,
#           "key_as_string": "2014-08-01"
#         },
#         {
#           "doc_count": 0,
#           "key": 1409529600000,
#           "key_as_string": "2014-09-01"
#         },
#         {
#           "doc_count": 1,
#           "key": 1412121600000,
#           "key_as_string": "2014-10-01"
#         },
#         {
#           "doc_count": 2,
#           "key": 1414800000000,
#           "key_as_string": "2014-11-01"
#         },
#         {
#           "doc_count": 0,
#           "key": 1417392000000,
#           "key_as_string": "2014-12-01"
#         }
#       ]
#     }
#   },
#   "hits": {
#     "hits": [],
#     "max_score": 0.0,
#     "total": 8
#   },
#   "timed_out": false,
#   "took": 5
# }

# %%
p(es.search(index='cars', doc_type='transactions', body={
        "size": 0,
        "aggs": {
            "sales": {
                "date_histogram": {
                    "field": "sold",
                    "interval": "quarter",
                    "format": "yyyy-MM-dd",
                    "min_doc_count": 0,
                    "extended_bounds": {
                        "min": "2014-01-01",
                        "max": "2014-12-31"
                    }
                },
                "aggs": {
                    "revenue": { "sum": { "field": "price" } },
                    "revenue_by_make": {
                        "terms": {
                            "field": "make"
                        },
                        "aggs": {
                            "revenue": { "sum": { "field": "price" }}
                        }
                    }
                }
            }
        }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "sales": {
#       "buckets": [
#         {
#           "doc_count": 2,
#           "key": 1388534400000,
#           "key_as_string": "2014-01-01",
#           "revenue": {
#             "value": 105000.0
#           },
#           "revenue_by_make": {
#             "buckets": [
#               {
#                 "doc_count": 1,
#                 "key": "bmw",
#                 "revenue": {
#                   "value": 80000.0
#                 }
#               },
#               {
#                 "doc_count": 1,
#                 "key": "ford",
#                 "revenue": {
#                   "value": 25000.0
#                 }
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         },
#         {
#           "doc_count": 1,
#           "key": 1396310400000,
#           "key_as_string": "2014-04-01",
#           "revenue": {
#             "value": 30000.0
#           },
#           "revenue_by_make": {
#             "buckets": [
#               {
#                 "doc_count": 1,
#                 "key": "ford",
#                 "revenue": {
#                   "value": 30000.0
#                 }
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         },
#         {
#           "doc_count": 2,
#           "key": 1404172800000,
#           "key_as_string": "2014-07-01",
#           "revenue": {
#             "value": 27000.0
#           },
#           "revenue_by_make": {
#             "buckets": [
#               {
#                 "doc_count": 2,
#                 "key": "toyota",
#                 "revenue": {
#                   "value": 27000.0
#                 }
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         },
#         {
#           "doc_count": 3,
#           "key": 1412121600000,
#           "key_as_string": "2014-10-01",
#           "revenue": {
#             "value": 50000.0
#           },
#           "revenue_by_make": {
#             "buckets": [
#               {
#                 "doc_count": 3,
#                 "key": "honda",
#                 "revenue": {
#                   "value": 50000.0
#                 }
#               }
#             ],
#             "doc_count_error_upper_bound": 0,
#             "sum_other_doc_count": 0
#           }
#         }
#       ]
#     }
#   },
#   "hits": {
#     "hits": [],
#     "max_score": 0.0,
#     "total": 8
#   },
#   "timed_out": false,
#   "took": 4
# }

# %%
p(es.search(index='cars', doc_type='transactions', body={
        "query": {
            "match": {
                "make": "ford"
            }
        },
        "aggs": {
            "colors": {
                "terms": { "field": "color" }
            }
        }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "colors": {
#       "buckets": [
#         {
#           "doc_count": 1,
#           "key": "blue"
#         },
#         {
#           "doc_count": 1,
#           "key": "green"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     }
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "AVg96eykbCBjQi1n-k6a",
#         "_index": "cars",
#         "_score": 1.4054651,
#         "_source": {
#           "color": "green",
#           "make": "ford",
#           "price": 30000,
#           "sold": "2014-05-18"
#         },
#         "_type": "transactions"
#       },
#       {
#         "_id": "AVg96eylbCBjQi1n-k6f",
#         "_index": "cars",
#         "_score": 1.0,
#         "_source": {
#           "color": "blue",
#           "make": "ford",
#           "price": 25000,
#           "sold": "2014-02-12"
#         },
#         "_type": "transactions"
#       }
#     ],
#     "max_score": 1.4054651,
#     "total": 2
#   },
#   "timed_out": false,
#   "took": 5
# }

# %%
p(es.search(index='cars', doc_type='transactions', body={
        "query": {
            "match": { "make": "ford" }
        },
        "aggs": {
            "single_avg_price": {
                "avg": { "field": "price" }
            },
            "all": {
                "global": {},
                "aggs": {
                    "avg_price": { "avg": { "field": "price" }}
                }
            }
        }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "all": {
#       "avg_price": {
#         "value": 26500.0
#       },
#       "doc_count": 8
#     },
#     "single_avg_price": {
#       "value": 27500.0
#     }
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "AVg96eykbCBjQi1n-k6a",
#         "_index": "cars",
#         "_score": 1.4054651,
#         "_source": {
#           "color": "green",
#           "make": "ford",
#           "price": 30000,
#           "sold": "2014-05-18"
#         },
#         "_type": "transactions"
#       },
#       {
#         "_id": "AVg96eylbCBjQi1n-k6f",
#         "_index": "cars",
#         "_score": 1.0,
#         "_source": {
#           "color": "blue",
#           "make": "ford",
#           "price": 25000,
#           "sold": "2014-02-12"
#         },
#         "_type": "transactions"
#       }
#     ],
#     "max_score": 1.4054651,
#     "total": 2
#   },
#   "timed_out": false,
#   "took": 5
# }

# %%
p(es.search(
        index='cars', doc_type='transactions', body={
            "size": 0,
            "query": {
                "constant_score": {
                    "filter": {
                        "range": {
                            "price": { "gt": 10000 }
                        }
                    }
                }
            },
            "aggs": {
                "avg_price": {
                    "avg": {"field": "price"}
                }
            }
    }), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "avg_price": {
#       "value": 28857.14285714286
#     }
#   },
#   "hits": {
#     "hits": [],
#     "max_score": 0.0,
#     "total": 7
#   },
#   "timed_out": false,
#   "took": 5
# }

# %% [markdown]
# ---
#
# Parent-child relationships
#
# ---

# %%
es.indices.create(
    index='company', body={
        "mappings": {
            "branch": {},
            "employee": {
                "_parent": {
                    "type": "branch"
                }
            }
        }
    })
# Out:
# {u'acknowledged': True}

# %%
helpers.bulk(es, index='company', doc_type='branch', actions=[
        { "_id": "london",    "name": "London Westminster", "city": "London", "country": "UK" },
        { "_id": "liverpool", "name": "Liverpool Central", "city": "Liverpool", "country": "UK" },
        { "_id": "paris",     "name": u"Champs Élysées", "city": "Paris", "country": "France" },
    ])
# Out:
# (3, [])

# %%
es.index(
    index='company', doc_type='employee', id='1', parent='london', body={
      "name":  "Alice Smith",
      "dob":   "1970-10-24",
      "hobby": "hiking"
    })
# Out:
# {u'_id': u'1',
#  u'_index': u'company',
#  u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#  u'_type': u'employee',
#  u'_version': 1,
#  u'created': True}

# %%
helpers.bulk(
    es, index='company', doc_type='employee', actions=[
        { "_id": 2, "_parent": "london", "name": "Mark Thomas", "dob": "1982-05-16", "hobby": "diving" },
        { "_id": 3, "_parent": "liverpool", "name": "Barry Smith", "dob": "1979-04-01", "hobby": "hiking" },
        { "_id": 4, "_parent": "paris", "name": "Adrien Grand", "dob": "1987-05-11", "hobby": "horses" },
    ]
)
# Out:
# (3, [])

# %%
p(es.search(
    index='company', doc_type='branch', body={
        "query": {
            "has_child": {
                "type": "employee",
                "query": {
                    "range": {
                        "dob": {
                            "gte": "1980-01-01"
                        }
                    }
                }
            }
        }
    }
), None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "paris",
#         "_index": "company",
#         "_score": 1.0,
#         "_source": {
#           "city": "Paris",
#           "country": "France",
#           "name": "Champs \u00c9lys\u00e9es"
#         },
#         "_type": "branch"
#       },
#       {
#         "_id": "london",
#         "_index": "company",
#         "_score": 1.0,
#         "_source": {
#           "city": "London",
#           "country": "UK",
#           "name": "London Westminster"
#         },
#         "_type": "branch"
#       }
#     ],
#     "max_score": 1.0,
#     "total": 2
#   },
#   "timed_out": false,
#   "took": 10
# }

# %%
p(
    es.search(
        index='company', doc_type='employee', body={
            "query": {
                "has_parent": {
                    "type": "branch",
                    "query": {
                        "match": {
                            "country": "UK"
                        }
                    }
                }
            }
        }
    ),
    None
)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "3",
#         "_index": "company",
#         "_parent": "liverpool",
#         "_routing": "liverpool",
#         "_score": 1.0,
#         "_source": {
#           "dob": "1979-04-01",
#           "hobby": "hiking",
#           "name": "Barry Smith"
#         },
#         "_type": "employee"
#       },
#       {
#         "_id": "1",
#         "_index": "company",
#         "_parent": "london",
#         "_routing": "london",
#         "_score": 1.0,
#         "_source": {
#           "dob": "1970-10-24",
#           "hobby": "hiking",
#           "name": "Alice Smith"
#         },
#         "_type": "employee"
#       },
#       {
#         "_id": "2",
#         "_index": "company",
#         "_parent": "london",
#         "_routing": "london",
#         "_score": 1.0,
#         "_source": {
#           "dob": "1982-05-16",
#           "hobby": "diving",
#           "name": "Mark Thomas"
#         },
#         "_type": "employee"
#       }
#     ],
#     "max_score": 1.0,
#     "total": 3
#   },
#   "timed_out": false,
#   "took": 5
# }

# %%
p(es.cluster.state(), None)
# Out:
# {
#   "blocks": {},
#   "cluster_name": "elasticsearch",
#   "master_node": "GAsmR5iBRj-DtwlTVPNIZA",
#   "metadata": {
#     "cluster_uuid": "k1vyrKjGQQOdfwGYCDBPdQ",
#     "indices": {
#       "blogs": {
#         "aliases": [],
#         "mappings": {},
#         "settings": {
#           "index": {
#             "creation_date": "1478273698129",
#             "number_of_replicas": "2",
#             "number_of_shards": "3",
#             "uuid": "JTNn6NNpROuaSNx3-AkUWw",
#             "version": {
#               "created": "2040199"
#             }
#           }
#         },
#         "state": "open"
#       },
#       "cars": {
#         "aliases": [],
#         "mappings": {
#           "transactions": {
#             "properties": {
#               "color": {
#                 "type": "string"
#               },
#               "make": {
#                 "type": "string"
#               },
#               "price": {
#                 "type": "long"
#               },
#               "sold": {
#                 "format": "strict_date_optional_time||epoch_millis",
#                 "type": "date"
#               }
#             }
#           }
#         },
#         "settings": {
#           "index": {
#             "creation_date": "1478507490374",
#             "number_of_replicas": "1",
#             "number_of_shards": "5",
#             "uuid": "i1hya_euQDyFI0tRUkuTPg",
#             "version": {
#               "created": "2040199"
#             }
#           }
#         },
#         "state": "open"
#       },
#       "company": {
#         "aliases": [],
#         "mappings": {
#           "branch": {
#             "properties": {
#               "city": {
#                 "type": "string"
#               },
#               "country": {
#                 "type": "string"
#               },
#               "name": {
#                 "type": "string"
#               }
#             }
#           },
#           "employee": {
#             "_parent": {
#               "type": "branch"
#             },
#             "_routing": {
#               "required": true
#             },
#             "properties": {
#               "dob": {
#                 "format": "strict_date_optional_time||epoch_millis",
#                 "type": "date"
#               },
#               "hobby": {
#                 "type": "string"
#               },
#               "name": {
#                 "type": "string"
#               }
#             }
#           }
#         },
#         "settings": {
#           "index": {
#             "creation_date": "1478512277475",
#             "number_of_replicas": "1",
#             "number_of_shards": "5",
#             "uuid": "E-F6fqPsRCyn9q_S85k1NA",
#             "version": {
#               "created": "2040199"
#             }
#           }
#         },
#         "state": "open"
#       },
#       "gb": {
#         "aliases": [],
#         "mappings": {
#           "tweet": {
#             "properties": {
#               "date": {
#                 "format": "strict_date_optional_time||epoch_millis",
#                 "type": "date"
#               },
#               "name": {
#                 "type": "string"
#               },
#               "tag": {
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "tweet": {
#                 "analyzer": "english",
#                 "type": "string"
#               },
#               "user_id": {
#                 "type": "long"
#               }
#             }
#           }
#         },
#         "settings": {
#           "index": {
#             "creation_date": "1478361296091",
#             "number_of_replicas": "1",
#             "number_of_shards": "5",
#             "uuid": "zN4jT4pfTbyX69hEpABBbg",
#             "version": {
#               "created": "2040199"
#             }
#           }
#         },
#         "state": "open"
#       },
#       "us": {
#         "aliases": [],
#         "mappings": {
#           "tweet": {
#             "properties": {
#               "date": {
#                 "format": "strict_date_optional_time||epoch_millis",
#                 "type": "date"
#               },
#               "name": {
#                 "type": "string"
#               },
#               "tweet": {
#                 "type": "string"
#               },
#               "user_id": {
#                 "type": "long"
#               }
#             }
#           },
#           "user": {
#             "properties": {
#               "email": {
#                 "type": "string"
#               },
#               "name": {
#                 "type": "string"
#               },
#               "username": {
#                 "type": "string"
#               }
#             }
#           }
#         },
#         "settings": {
#           "index": {
#             "creation_date": "1478291917391",
#             "number_of_replicas": "1",
#             "number_of_shards": "5",
#             "uuid": "5j34uPg5Tre3zl019xoO-w",
#             "version": {
#               "created": "2040199"
#             }
#           }
#         },
#         "state": "open"
#       }
#     },
#     "templates": {}
#   },
#   "nodes": {
#     "GAsmR5iBRj-DtwlTVPNIZA": {
#       "attributes": {},
#       "name": "Magician",
#       "transport_address": "127.0.0.1:9300"
#     }
#   },
#   "routing_nodes": {
#     "nodes": {
#       "GAsmR5iBRj-DtwlTVPNIZA": [
#         {
#           "allocation_id": {
#             "id": "bPripsxJTrOSU5EgXcVYpw"
#           },
#           "index": "cars",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 4,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "DTnkgbCxSWaO55WRlD_A4A"
#           },
#           "index": "cars",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 2,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "AAFIpzVfQlmTI8x45BLnbA"
#           },
#           "index": "cars",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 3,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "nADq4ojMRyGJXa-FzHaQnQ"
#           },
#           "index": "cars",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 1,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "yIgQJx6HSvGKCXt1S7IPwQ"
#           },
#           "index": "cars",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 0,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "2sltQlpGSS-_Nw256t1ORA"
#           },
#           "index": "company",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 4,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "Y_-tDNHRTqeb_lQxsGql2w"
#           },
#           "index": "company",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 2,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "y3DGBi-pRq-E7mLRVNo6_A"
#           },
#           "index": "company",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 3,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "0LmjBpaAThWR1jlu8brLeA"
#           },
#           "index": "company",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 1,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "f7PR2V09TfOctoe6viuJZg"
#           },
#           "index": "company",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 0,
#           "state": "STARTED",
#           "version": 2
#         },
#         {
#           "allocation_id": {
#             "id": "lBkPuPmWS6G7yHKSx_f_tA"
#           },
#           "index": "gb",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 1,
#           "state": "STARTED",
#           "version": 4
#         },
#         {
#           "allocation_id": {
#             "id": "T9wmAoLAQe2U606qFNUFbQ"
#           },
#           "index": "gb",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 2,
#           "state": "STARTED",
#           "version": 4
#         },
#         {
#           "allocation_id": {
#             "id": "UlkzfhGLSwG4f1Z4WnJjMQ"
#           },
#           "index": "gb",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 3,
#           "state": "STARTED",
#           "version": 4
#         },
#         {
#           "allocation_id": {
#             "id": "ta_tXOAhTD23Ghww9A5dpQ"
#           },
#           "index": "gb",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 4,
#           "state": "STARTED",
#           "version": 4
#         },
#         {
#           "allocation_id": {
#             "id": "hv3NbIjpQaOubHVw31ZOmw"
#           },
#           "index": "gb",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 0,
#           "state": "STARTED",
#           "version": 4
#         },
#         {
#           "allocation_id": {
#             "id": "B3Ggq1jYQcuy8Gjv5OBCnw"
#           },
#           "index": "us",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 4,
#           "state": "STARTED",
#           "version": 6
#         },
#         {
#           "allocation_id": {
#             "id": "lEfJXrPVQxKqKvGnxUul9g"
#           },
#           "index": "us",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 2,
#           "state": "STARTED",
#           "version": 6
#         },
#         {
#           "allocation_id": {
#             "id": "EAAsJ23wSsWmnws6qyDApQ"
#           },
#           "index": "us",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 3,
#           "state": "STARTED",
#           "version": 6
#         },
#         {
#           "allocation_id": {
#             "id": "m0etjNsZQuaJeyA_5owpJg"
#           },
#           "index": "us",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 1,
#           "state": "STARTED",
#           "version": 6
#         },
#         {
#           "allocation_id": {
#             "id": "4V5YPY_kRwiWXN3WC2O9xQ"
#           },
#           "index": "us",
#           "node": "GAsmR5iBRj-DtwlTVPNIZA",
#           "primary": true,
#           "relocating_node": null,
#           "shard": 0,
#           "state": "STARTED",
#           "version": 6
#         }
#       ]
#     },
#     "unassigned": [
#       {
#         "index": "cars",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 4,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:31:30.395Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "cars",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 2,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:31:30.395Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "cars",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 3,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:31:30.395Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "cars",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 1,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:31:30.395Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "cars",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 0,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:31:30.395Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "blogs",
#         "node": null,
#         "primary": true,
#         "relocating_node": null,
#         "shard": 2,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 0
#       },
#       {
#         "index": "blogs",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 2,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 0
#       },
#       {
#         "index": "blogs",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 2,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 0
#       },
#       {
#         "index": "blogs",
#         "node": null,
#         "primary": true,
#         "relocating_node": null,
#         "shard": 1,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 0
#       },
#       {
#         "index": "blogs",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 1,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 0
#       },
#       {
#         "index": "blogs",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 1,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 0
#       },
#       {
#         "index": "blogs",
#         "node": null,
#         "primary": true,
#         "relocating_node": null,
#         "shard": 0,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 0
#       },
#       {
#         "index": "blogs",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 0,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 0
#       },
#       {
#         "index": "blogs",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 0,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 0
#       },
#       {
#         "index": "company",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 4,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T09:51:17.488Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "company",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 2,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T09:51:17.488Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "company",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 3,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T09:51:17.488Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "company",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 1,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T09:51:17.488Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "company",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 0,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T09:51:17.488Z",
#           "reason": "INDEX_CREATED"
#         },
#         "version": 2
#       },
#       {
#         "index": "gb",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 1,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 4
#       },
#       {
#         "index": "gb",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 2,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 4
#       },
#       {
#         "index": "gb",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 3,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 4
#       },
#       {
#         "index": "gb",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 4,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 4
#       },
#       {
#         "index": "gb",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 0,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.560Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 4
#       },
#       {
#         "index": "us",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 4,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.556Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 6
#       },
#       {
#         "index": "us",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 2,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.556Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 6
#       },
#       {
#         "index": "us",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 3,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.556Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 6
#       },
#       {
#         "index": "us",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 1,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.556Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 6
#       },
#       {
#         "index": "us",
#         "node": null,
#         "primary": false,
#         "relocating_node": null,
#         "shard": 0,
#         "state": "UNASSIGNED",
#         "unassigned_info": {
#           "at": "2016-11-07T08:26:44.556Z",
#           "reason": "CLUSTER_RECOVERED"
#         },
#         "version": 6
#       }
#     ]
#   },
#   "routing_table": {
#     "indices": {
#       "blogs": {
#         "shards": {
#           "0": [
#             {
#               "index": "blogs",
#               "node": null,
#               "primary": true,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 0
#             },
#             {
#               "index": "blogs",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 0
#             },
#             {
#               "index": "blogs",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 0
#             }
#           ],
#           "1": [
#             {
#               "index": "blogs",
#               "node": null,
#               "primary": true,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 0
#             },
#             {
#               "index": "blogs",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 0
#             },
#             {
#               "index": "blogs",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 0
#             }
#           ],
#           "2": [
#             {
#               "index": "blogs",
#               "node": null,
#               "primary": true,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 0
#             },
#             {
#               "index": "blogs",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 0
#             },
#             {
#               "index": "blogs",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 0
#             }
#           ]
#         }
#       },
#       "cars": {
#         "shards": {
#           "0": [
#             {
#               "allocation_id": {
#                 "id": "yIgQJx6HSvGKCXt1S7IPwQ"
#               },
#               "index": "cars",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "cars",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:31:30.395Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ],
#           "1": [
#             {
#               "allocation_id": {
#                 "id": "nADq4ojMRyGJXa-FzHaQnQ"
#               },
#               "index": "cars",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "cars",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:31:30.395Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ],
#           "2": [
#             {
#               "allocation_id": {
#                 "id": "DTnkgbCxSWaO55WRlD_A4A"
#               },
#               "index": "cars",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "cars",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:31:30.395Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ],
#           "3": [
#             {
#               "allocation_id": {
#                 "id": "AAFIpzVfQlmTI8x45BLnbA"
#               },
#               "index": "cars",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 3,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "cars",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 3,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:31:30.395Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ],
#           "4": [
#             {
#               "allocation_id": {
#                 "id": "bPripsxJTrOSU5EgXcVYpw"
#               },
#               "index": "cars",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 4,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "cars",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 4,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:31:30.395Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ]
#         }
#       },
#       "company": {
#         "shards": {
#           "0": [
#             {
#               "allocation_id": {
#                 "id": "f7PR2V09TfOctoe6viuJZg"
#               },
#               "index": "company",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "company",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T09:51:17.488Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ],
#           "1": [
#             {
#               "allocation_id": {
#                 "id": "0LmjBpaAThWR1jlu8brLeA"
#               },
#               "index": "company",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "company",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T09:51:17.488Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ],
#           "2": [
#             {
#               "allocation_id": {
#                 "id": "Y_-tDNHRTqeb_lQxsGql2w"
#               },
#               "index": "company",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "company",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T09:51:17.488Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ],
#           "3": [
#             {
#               "allocation_id": {
#                 "id": "y3DGBi-pRq-E7mLRVNo6_A"
#               },
#               "index": "company",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 3,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "company",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 3,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T09:51:17.488Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ],
#           "4": [
#             {
#               "allocation_id": {
#                 "id": "2sltQlpGSS-_Nw256t1ORA"
#               },
#               "index": "company",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 4,
#               "state": "STARTED",
#               "version": 2
#             },
#             {
#               "index": "company",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 4,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T09:51:17.488Z",
#                 "reason": "INDEX_CREATED"
#               },
#               "version": 2
#             }
#           ]
#         }
#       },
#       "gb": {
#         "shards": {
#           "0": [
#             {
#               "allocation_id": {
#                 "id": "hv3NbIjpQaOubHVw31ZOmw"
#               },
#               "index": "gb",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "STARTED",
#               "version": 4
#             },
#             {
#               "index": "gb",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 4
#             }
#           ],
#           "1": [
#             {
#               "allocation_id": {
#                 "id": "lBkPuPmWS6G7yHKSx_f_tA"
#               },
#               "index": "gb",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "STARTED",
#               "version": 4
#             },
#             {
#               "index": "gb",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 4
#             }
#           ],
#           "2": [
#             {
#               "allocation_id": {
#                 "id": "T9wmAoLAQe2U606qFNUFbQ"
#               },
#               "index": "gb",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "STARTED",
#               "version": 4
#             },
#             {
#               "index": "gb",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 4
#             }
#           ],
#           "3": [
#             {
#               "allocation_id": {
#                 "id": "UlkzfhGLSwG4f1Z4WnJjMQ"
#               },
#               "index": "gb",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 3,
#               "state": "STARTED",
#               "version": 4
#             },
#             {
#               "index": "gb",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 3,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 4
#             }
#           ],
#           "4": [
#             {
#               "allocation_id": {
#                 "id": "ta_tXOAhTD23Ghww9A5dpQ"
#               },
#               "index": "gb",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 4,
#               "state": "STARTED",
#               "version": 4
#             },
#             {
#               "index": "gb",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 4,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.560Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 4
#             }
#           ]
#         }
#       },
#       "us": {
#         "shards": {
#           "0": [
#             {
#               "allocation_id": {
#                 "id": "4V5YPY_kRwiWXN3WC2O9xQ"
#               },
#               "index": "us",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "STARTED",
#               "version": 6
#             },
#             {
#               "index": "us",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 0,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.556Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 6
#             }
#           ],
#           "1": [
#             {
#               "allocation_id": {
#                 "id": "m0etjNsZQuaJeyA_5owpJg"
#               },
#               "index": "us",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "STARTED",
#               "version": 6
#             },
#             {
#               "index": "us",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 1,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.556Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 6
#             }
#           ],
#           "2": [
#             {
#               "allocation_id": {
#                 "id": "lEfJXrPVQxKqKvGnxUul9g"
#               },
#               "index": "us",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "STARTED",
#               "version": 6
#             },
#             {
#               "index": "us",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 2,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.556Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 6
#             }
#           ],
#           "3": [
#             {
#               "allocation_id": {
#                 "id": "EAAsJ23wSsWmnws6qyDApQ"
#               },
#               "index": "us",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 3,
#               "state": "STARTED",
#               "version": 6
#             },
#             {
#               "index": "us",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 3,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.556Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 6
#             }
#           ],
#           "4": [
#             {
#               "allocation_id": {
#                 "id": "B3Ggq1jYQcuy8Gjv5OBCnw"
#               },
#               "index": "us",
#               "node": "GAsmR5iBRj-DtwlTVPNIZA",
#               "primary": true,
#               "relocating_node": null,
#               "shard": 4,
#               "state": "STARTED",
#               "version": 6
#             },
#             {
#               "index": "us",
#               "node": null,
#               "primary": false,
#               "relocating_node": null,
#               "shard": 4,
#               "state": "UNASSIGNED",
#               "unassigned_info": {
#                 "at": "2016-11-07T08:26:44.556Z",
#                 "reason": "CLUSTER_RECOVERED"
#               },
#               "version": 6
#             }
#           ]
#         }
#       }
#     }
#   },
#   "state_uuid": "WfRDyUTMTNio6amp_SRQTQ",
#   "version": 123
# }
