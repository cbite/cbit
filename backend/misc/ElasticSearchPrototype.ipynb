# %% [markdown]
# # ElasticSearch prototype
#
# Now that I've gone through all the notes on `ElasticSearch: The Definite Guide`, I have a much better idea of how to set up the store and related queries.

# %%
import elasticsearch
from elasticsearch import helpers
import json

def p(doc, max_lines=25):
    lines = json.dumps(doc, indent=2, sort_keys=True).split('\n')
    if not max_lines or len(lines) <= max_lines:
        print('\n'.join(lines))
    else:
        print('\n'.join(lines[:max_lines/2]) + '\n...\n' + '\n'.join(lines[-max_lines/2:]))

# %%
es = elasticsearch.Elasticsearch(hosts=[{'host': 'localhost', 'port': 9200}])

# %%
es.index?

# %%
es.indices.exists('cbit')
# Out:
# True

# %%
# Clear everything
es.indices.delete(index='*')
# Out:
# {u'acknowledged': True}

# %%
# Set up index (v1)
# "study" and "sample" need to live in the same index to set up a parent-child relationship
es.indices.create(index='cbit', body={
        "settings": {
            # Set up indexing to support efficient search-as-you-type
            # (see https://www.elastic.co/guide/en/elasticsearch/guide/current/_index_time_search_as_you_type.html)
            "analysis": {
                "filter": {
                    "autocomplete_filter": { 
                        "type":     "edge_ngram",
                        "min_gram": 1,
                        "max_gram": 20
                    }
                },
                "analyzer": {
                    "autocomplete": {
                        "type":      "custom",
                        "tokenizer": "standard",
                        "filter": [
                            "lowercase",
                            "autocomplete_filter" 
                        ]
                    }
                }
            }            
        },
        
        "mappings": {
            "study": {
                # Prevent creation of dynamic fields
                # (when adding studies with new fields, these should be presented to the
                #  user for explicit typing)
                #"dynamic": "strict",
                # TODO: For the moment, though, allow dynamic mapping, just ensure that 
                # everything is mapped as a string below
                "dynamic": True,

                "dynamic_templates": [
                    {
                        # Some fields are objects (names are all in uppercase)
                        "object_fields": {
                            "match_pattern": "regex",
                            "path_match": r"^([A-Z ]+)$",
                            "mapping": {
                                "type": "object"
                            }
                        }
                    },
                    
                    {    
                        # Some fields should have full-text search enabled
                        "fts_fields": {
                            "match_pattern": "regex",
                            "path_match": r"^.*\.({0})$".format("|".join([
                                        "Study Researchers Involved",
                                        "Study PubMed ID",
                                        "Study Publication Author List",
                                    ])),
                            "mapping": {
                                # Everything is a string for now (improve this during Sprint #3)
                                "type": "string",

                                # Make sure that all matches are done by exact content
                                # (full-text search is done against the _all field, which *is* analyzed)
                                "index": "not_analyzed",

                                "include_in_all": True
                            }
                        }
                    },
                    
                    {
                        # Everything else is excluded from full-text search
                        "default": {
                            "match": "*",
                            "mapping": {
                                # Everything is a string for now (improve this during Sprint #3)
                                "type": "string",

                                # Make sure that all matches are done by exact content
                                # (full-text search is done against the _all field, which *is* analyzed)
                                "index": "not_analyzed",

                                "include_in_all": False
                            }
                        }
                    }
                ],

                "_all": {
                    # Do analyze everything in the study metadata that can be searched by
                    # full-text search.  Use autocomplete analyzer above to split words on
                    # word boundaries, lowercase everything and produce edge n-grams in index.
                    # But don't produce edge n-grams during searching
                    "index": "analyzed",
                    "analyzer": "autocomplete",
                    "search_analyzer": "standard"
                },
            },
            
            "sample": {
                
                # Set up parent-child relationship with `study`
                "_parent": {
                    "type": "study"
                },
                
                # Prevent creation of dynamic fields
                # (when adding studies with new fields, these should be presented to the
                #  user for explicit typing)
                #"dynamic": "strict",
                # TODO: For the moment, though, allow dynamic mapping, just ensure that 
                # everything is mapped as a string below
                "dynamic": True,

                "dynamic_templates": [
                    {
                        # Everything sample metadata is full-text searchable
                        "default": {
                            "match": "*",
                            "mapping": {
                                # Everything is a string for now (improve this during Sprint #3)
                                "type": "string",

                                # Make sure that all matches are done by exact content
                                # (full-text search is done against the _all field, which *is* analyzed)
                                "index": "not_analyzed",

                                "include_in_all": True
                            }
                        }
                    }
                ],

                "_all": {
                    # Do analyze everything in the study metadata that can be searched by
                    # full-text search.  Use autocomplete analyzer above to split words on
                    # word boundaries, lowercase everything and produce edge n-grams in index.
                    # But don't produce edge n-grams during searching
                    "index": "analyzed",
                    "analyzer": "autocomplete",
                    "search_analyzer": "standard"
                },
            }
        }
    })
# Out:
# {u'acknowledged': True}

# %%
# Make an alias to study_v1
#es.indices.put_alias(name='study', index='study_v1')

# %%
# Check
p(es.indices.get(index='cbit'), None)
# Out:
# {
#   "cbit": {
#     "aliases": {},
#     "mappings": {
#       "sample": {
#         "_all": {
#           "analyzer": "autocomplete",
#           "search_analyzer": "standard"
#         },
#         "_parent": {
#           "type": "study"
#         },
#         "_routing": {
#           "required": true
#         },
#         "dynamic": "true",
#         "dynamic_templates": [
#           {
#             "default": {
#               "mapping": {
#                 "include_in_all": true,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "match": "*"
#             }
#           }
#         ]
#       },
#       "study": {
#         "_all": {
#           "analyzer": "autocomplete",
#           "search_analyzer": "standard"
#         },
#         "dynamic": "true",
#         "dynamic_templates": [
#           {
#             "object_fields": {
#               "mapping": {
#                 "type": "object"
#               },
#               "match_pattern": "regex",
#               "path_match": "^([A-Z ]+)$"
#             }
#           },
#           {
#             "fts_fields": {
#               "mapping": {
#                 "include_in_all": true,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "match_pattern": "regex",
#               "path_match": "^.*\\.(Study Researchers Involved|Study PubMed ID|Study Publication Author List)$"
#             }
#           },
#           {
#             "default": {
#               "mapping": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "match": "*"
#             }
#           }
#         ]
#       }
#     },
#     "settings": {
#       "index": {
#         "analysis": {
#           "analyzer": {
#             "autocomplete": {
#               "filter": [
#                 "lowercase",
#                 "autocomplete_filter"
#               ],
#               "tokenizer": "standard",
#               "type": "custom"
#             }
#           },
#           "filter": {
#             "autocomplete_filter": {
#               "max_gram": "20",
#               "min_gram": "1",
#               "type": "edge_ngram"
#             }
#           }
#         },
#         "creation_date": "1478702254208",
#         "number_of_replicas": "1",
#         "number_of_shards": "5",
#         "uuid": "Vn-_KARgRuychcyIEJJ89w",
#         "version": {
#           "created": "2040199"
#         }
#       }
#     },
#     "warmers": {}
#   }
# }

# %%
# Set up samples index (v1)
if False:
    es.indices.create(index='sample_v1', body={
            "settings": {
                # Set up indexing to support efficient search-as-you-type
                # (see https://www.elastic.co/guide/en/elasticsearch/guide/current/_index_time_search_as_you_type.html)
                "analysis": {
                    "filter": {
                        "autocomplete_filter": { 
                            "type":     "edge_ngram",
                            "min_gram": 1,
                            "max_gram": 20
                        }
                    },
                    "analyzer": {
                        "autocomplete": {
                            "type":      "custom",
                            "tokenizer": "standard",
                            "filter": [
                                "lowercase",
                                "autocomplete_filter" 
                            ]
                        }
                    }
                }            
            },

            "mappings": {
                "sample": {  # Only one doc_type

                    # Set up parent-child relationship with `study`
                    "_parent": {
                        "type": "study_v1"
                    },

                    # Prevent creation of dynamic fields
                    # (when adding studies with new fields, these should be presented to the
                    #  user for explicit typing)
                    #"dynamic": "strict",
                    # TODO: For the moment, though, allow dynamic mapping, just ensure that 
                    # everything is mapped as a string below
                    "dynamic": True,

                    "dynamic_templates": [
                        {
                            # Everything sample metadata is full-text searchable
                            "default": {
                                "match": "*",
                                "mapping": {
                                    # Everything is a string for now (improve this during Sprint #3)
                                    "type": "string",

                                    # Make sure that all matches are done by exact content
                                    # (full-text search is done against the _all field, which *is* analyzed)
                                    "index": "not_analyzed",

                                    "include_in_all": True
                                }
                            }
                        }
                    ],

                    "_all": {
                        # Do analyze everything in the study metadata that can be searched by
                        # full-text search.  Use autocomplete analyzer above to split words on
                        # word boundaries, lowercase everything and produce edge n-grams in index.
                        # But don't produce edge n-grams during searching
                        "index": "analyzed",
                        "analyzer": "autocomplete",
                        "search_analyzer": "standard"
                    },
                }
            }
        })

# %%
# Make an alias to sample_v1
#es.indices.put_alias(name='sample', index='sample_v1')

# %%
# Check
#p(es.indices.get(index='sample'), None)

# %%
import reader, config, json
cfg = config.Config()

i = reader.read_investigation(cfg, open('../../data/new_ISAcreatorArchives/StudyID_01_archive/i_Investigation.txt', 'r'))
result = reader.conform_investigation_to_schema(
                reader.remove_isa_name_prefixes(
                  reader.remove_empty_values_in_dict(
                    reader.flatten_investigation(
                      i
                    )
                  )
                )
              )

response = es.index(index='cbit', doc_type='study', body=result)
study1_id = response['_id']
response
# Out:
# {u'_id': u'AVhJhfxO8X1My4__bYgD',
#  u'_index': u'cbit',
#  u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#  u'_type': u'study',
#  u'_version': 1,
#  u'created': True}

# %%
i = reader.read_investigation(cfg, open('../../data/new_ISAcreatorArchives/StudyID_02_archive/i_Investigation.txt', 'r'))
result = reader.conform_investigation_to_schema(
               reader.remove_isa_name_prefixes(
                 reader.remove_empty_values_in_dict(
                   reader.flatten_investigation(
                     i
                   )
                 )
               )
             )
response = es.index(index='cbit', doc_type='study', body=result)
study2_id = response['_id']
response
# Out:
# {u'_id': u'AVhJhnMu8X1My4__bYgF',
#  u'_index': u'cbit',
#  u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#  u'_type': u'study',
#  u'_version': 1,
#  u'created': True}

# %%
# Check dynamic mappings for studies
p(es.indices.get_mapping(index='cbit', doc_type='study'), None)
# Out:
# {
#   "cbit": {
#     "mappings": {
#       "study": {
#         "_all": {
#           "analyzer": "autocomplete",
#           "search_analyzer": "standard"
#         },
#         "dynamic": "true",
#         "dynamic_templates": [
#           {
#             "object_fields": {
#               "mapping": {
#                 "type": "object"
#               },
#               "match_pattern": "regex",
#               "path_match": "^([A-Z ]+)$"
#             }
#           },
#           {
#             "fts_fields": {
#               "mapping": {
#                 "include_in_all": true,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "match_pattern": "regex",
#               "path_match": "^.*\\.(Study Researchers Involved|Study PubMed ID|Study Publication Author List)$"
#             }
#           },
#           {
#             "default": {
#               "mapping": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "match": "*"
#             }
#           }
#         ],
#         "properties": {
#           "INVESTIGATION": {
#             "properties": {
#               "Investigation Identifier": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Investigation Title": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               }
#             }
#           },
#           "ONTOLOGY SOURCE REFERENCE": {
#             "properties": {
#               "Term Source Description": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Term Source File": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Term Source Name": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Term Source Version": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               }
#             }
#           },
#           "STUDY": {
#             "properties": {
#               "Study Description": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study File Name": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Identifier": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Public Release Date": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Researchers Involved": {
#                 "include_in_all": true,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Submission Date": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Title": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               }
#             }
#           },
#           "STUDY ASSAYS": {
#             "properties": {
#               "Study Assay File Name": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Assay Measurement Type": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Assay Technology Platform": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Assay Technology Type": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               }
#             }
#           },
#           "STUDY CONTACTS": {
#             "properties": {
#               "Study Person Affiliation": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Person First Name": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Person Last Name": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               }
#             }
#           },
#           "STUDY DESIGN DESCRIPTORS": {
#             "properties": {
#               "Study Design Type": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               }
#             }
#           },
#           "STUDY FACTORS": {
#             "properties": {
#               "Study Factor Name": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Factor Type": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               }
#             }
#           },
#           "STUDY PROTOCOLS": {
#             "properties": {
#               "Study Protocol Description": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Protocol Name": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Protocol Parameters Name": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Protocol Type": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               }
#             }
#           },
#           "STUDY PUBLICATIONS": {
#             "properties": {
#               "Study PubMed ID": {
#                 "include_in_all": true,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Publication Author List": {
#                 "include_in_all": true,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Publication DOI": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Publication Status": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Publication Status Term Accession Number": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Publication Status Term Source REF": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "Study Publication Title": {
#                 "include_in_all": false,
#                 "index": "not_analyzed",
#                 "type": "string"
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }

# %%
# Full-text search by Pubmed Id
p(es.search(index='cbit', doc_type='study', body={
        "query": {
            "match_phrase": {
                "_all": "22646480"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved']
    }))
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "AVhJhfxO8X1My4__bYgD",
#         "_index": "cbit",
#         "_score": 0.047945753,
# ...
#             "Study Researchers Involved": "Doorn J, Leusink M, Groen N, van de Peppel J, van Leeuwen JP, van Blitterswijk CA, de Boer J",
#             "Study Title": "Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells"
#           }
#         },
#         "_type": "study"
#       }
#     ],
#     "max_score": 0.047945753,
#     "total": 1
#   },
#   "timed_out": false,
#   "took": 66
# }

# %%
# Full-text search by Pubmed Id prefix
p(es.search(index='cbit', doc_type='study', body={
        "query": {
            "match_phrase": {
                "_all": "226", #"22646480"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved']
    }))
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "AVhJhfxO8X1My4__bYgD",
#         "_index": "cbit",
#         "_score": 0.047945753,
# ...
#             "Study Researchers Involved": "Doorn J, Leusink M, Groen N, van de Peppel J, van Leeuwen JP, van Blitterswijk CA, de Boer J",
#             "Study Title": "Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells"
#           }
#         },
#         "_type": "study"
#       }
#     ],
#     "max_score": 0.047945753,
#     "total": 1
#   },
#   "timed_out": false,
#   "took": 5
# }

# %%
# Full-text search by researcher last name
p(es.search(index='cbit', doc_type='study', body={
        "query": {
            "match_phrase": {
                "_all": "Doorn"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved']
    }))
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "AVhJhfxO8X1My4__bYgD",
#         "_index": "cbit",
#         "_score": 0.06780553,
# ...
#             "Study Researchers Involved": "Doorn J, Leusink M, Groen N, van de Peppel J, van Leeuwen JP, van Blitterswijk CA, de Boer J",
#             "Study Title": "Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells"
#           }
#         },
#         "_type": "study"
#       }
#     ],
#     "max_score": 0.06780553,
#     "total": 1
#   },
#   "timed_out": false,
#   "took": 4
# }

# %%
# Full-text search by researcher last name (partial)
p(es.search(index='cbit', doc_type='study', body={
        "query": {
            "match_phrase": {
                "_all": "door"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved']
    }))
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "AVhJhfxO8X1My4__bYgD",
#         "_index": "cbit",
#         "_score": 0.06780553,
# ...
#             "Study Researchers Involved": "Doorn J, Leusink M, Groen N, van de Peppel J, van Leeuwen JP, van Blitterswijk CA, de Boer J",
#             "Study Title": "Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells"
#           }
#         },
#         "_type": "study"
#       }
#     ],
#     "max_score": 0.06780553,
#     "total": 1
#   },
#   "timed_out": false,
#   "took": 4
# }

# %%
# Full-text search by researcher last name (partial)
p(es.search(index='cbit', doc_type='study', body={
        "query": {
            "match_phrase": {
                "_all": "de boe"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved']
    }))
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "AVhJhgFs8X1My4__bYgE",
#         "_index": "cbit",
#         "_score": 0.13561106,
# ...
#             "Study Researchers Involved": "Groen N, van de Peppel J, Yuan H, van Leeuwen JP, van Blitterswijk CA, de Boer J",
#             "Study Title": "Bioinformatics-based selection of a model cell type for in vitro biomaterial testing"
#           }
#         },
#         "_type": "study"
#       }
#     ],
#     "max_score": 0.13561106,
#     "total": 3
#   },
#   "timed_out": false,
#   "took": 17
# }

# %%
# Full-text search by researcher last name (fail due to wrong ordering)
p(es.search(index='cbit', doc_type='study', body={
        "query": {
            "match_phrase": {
                "_all": "de boer doorn"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved']
    }))
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [],
#     "max_score": null,
#     "total": 0
#   },
#   "timed_out": false,
#   "took": 4
# }

# %%
# Load all samples
import reader, config, json
cfg = config.Config()
a = reader.read_assay(cfg, open('../../data/new_ISAcreatorArchives/StudyID_01_archive/a_transcription_micro_1.txt', 'r'))
s = reader.read_study_sample(cfg, open('../../data/new_ISAcreatorArchives/StudyID_01_archive/s_study_sample.txt', 'r'))
d = reader.join_study_sample_and_assay(reader.clean_up_study_samples(s), reader.clean_up_assay(a))
d = reader.apply_special_treatments_to_study_sample(d)
a2 = reader.read_assay(cfg, open('../../data/new_ISAcreatorArchives/StudyID_02_archive/a_transcription_micro_1.txt', 'r'))
s2 = reader.read_study_sample(cfg, open('../../data/new_ISAcreatorArchives/StudyID_02_archive/s_study_sample.txt', 'r'))
d2 = reader.join_study_sample_and_assay(reader.clean_up_study_samples(s2), reader.clean_up_assay(a2))
d2 = reader.apply_special_treatments_to_study_sample(d2)

result = []

for i, (k, v) in enumerate(d.iteritems()):
    vv = v.copy()
    vv['Sample Name'] = k
    vv['_parent'] = study1_id
    result.append(vv)

for i, (k, v) in enumerate(d2.iteritems()):
    vv = v.copy()
    vv['Sample Name'] = k
    vv['_parent'] = study2_id
    result.append(vv)

helpers.bulk(es, index='cbit', doc_type='sample', actions=result)
# Out:
# (72, [])

# %%
# Full-text search everywhere
result = es.search(index='cbit', body={
        "size": 100,
        "query": {
            "match_phrase": {
                "_all": "d"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
# Out:
# 2
# [u'Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells', u'Bioinformatics-based selection of a model cell type for in vitro biomaterial testing']

# %%
# Full-text search everywhere
result = es.search(index='cbit', body={
        "size": 100,
        "query": {
            "match_phrase": {
                "_all": "db"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
# Out:
# 6
# [u'5342595019_E', u'5342595019_B', u'5342595019_H', u'5342595028_H', u'5342595028_E', u'5342595028_B']

# %%
# Full-text search everywhere
result = es.search(index='cbit', body={
        "size": 100,
        "query": {
            "match_phrase": {
                "_all": "db-camp"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
# Out:
# 6
# [u'5342595019_E', u'5342595019_B', u'5342595019_H', u'5342595028_H', u'5342595028_E', u'5342595028_B']

# %%
# Full-text search everywhere
result = es.search(index='cbit', body={
        "size": 100,
        "query": {
            "match_phrase": {
                "_all": "c"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
# Out:
# 74
# [u'5937337021_A', u'5937337049_H', u'5937337059_I', u'5937337061_A', u'5937337044_K', u'5937337061_B', u'5937337021_F', u'5937337059_C', u'5937337059_F', u'5937337044_I', u'5937337044_C', u'5937337044_F', u'5342595019_E', u'5342595019_F', u'5342595019_B', u'5342595019_C', u'5342595019_H', u'5342595019_I', u'5342595028_H', u'5342595028_I', u'5342595028_E', u'5342595028_F', u'5342595028_B', u'5342595028_C', u'5937337021_G', u'5937337059_G', u'5937337061_D', u'5937337021_E', u'5937337059_E', u'5937337021_B', u'5937337021_L', u'5937337044_J', u'5937337044_A', u'5937337021_I', u'5937337059_B', u'5937337049_L', u'5937337059_J', u'5937337021_H', u'5937337021_J', u'5937337044_E', u'5937337059_D', u'5937337049_K', u'5937337049_I', u'5937337049_A', u'5937337061_E', u'5937337049_D', u'5937337044_H', u'5937337049_F', u'5937337049_C', u'5937337061_C', u'5937337061_F', u'5342595019_D', u'5342595019_G', u'5342595019_A', u'5342595028_D', u'5342595028_G', u'5342595028_A', u'Bioinformatics-based selection of a model cell type for in vitro biomaterial testing', u'5937337059_K', u'5937337059_A', u'5937337049_E', u'5937337021_D', u'5937337021_C', u'5937337059_H', u'5937337059_L', u'5937337021_K', u'5937337049_J', u'5937337049_G', u'5937337049_B', u'5937337044_B', u'5937337044_G', u'5937337044_D', u'5937337044_L', u'Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells']

# %%
# Full-text search everywhere
result = es.search(index='cbit', body={
        "size": 100,
        "query": {
            "match_phrase": {
                "_all": "ca"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
# Out:
# 32
# [u'Bioinformatics-based selection of a model cell type for in vitro biomaterial testing', u'5937337044_I', u'5937337044_C', u'5937337044_F', u'5937337049_D', u'5937337021_I', u'5937337021_G', u'5937337021_F', u'5937337059_B', u'5937337059_C', u'5937337044_H', u'5937337049_L', u'5937337059_F', u'5937337049_F', u'5937337059_G', u'5937337049_C', u'5937337061_C', u'5937337061_D', u'5937337061_F', u'Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells', u'5342595019_E', u'5342595019_F', u'5342595019_B', u'5342595019_C', u'5342595019_H', u'5342595019_I', u'5342595028_H', u'5342595028_I', u'5342595028_E', u'5342595028_F', u'5342595028_B', u'5342595028_C']

# %%
# Full-text search everywhere
result = es.search(index='cbit', body={
        "size": 100,
        "query": {
            "match_phrase": {
                "_all": "cam"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
# Out:
# 12
# [u'5342595019_E', u'5342595019_F', u'5342595019_B', u'5342595019_C', u'5342595019_H', u'5342595019_I', u'5342595028_H', u'5342595028_I', u'5342595028_E', u'5342595028_F', u'5342595028_B', u'5342595028_C']

# %%
# Full-text search everywhere
result = es.search(index='cbit', body={
        "size": 100,
        "query": {
            "match_phrase": {
                "_all": "camp"
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
# Out:
# 12
# [u'5342595019_E', u'5342595019_F', u'5342595019_B', u'5342595019_C', u'5342595019_H', u'5342595019_I', u'5342595028_H', u'5342595028_I', u'5342595028_E', u'5342595028_F', u'5342595028_B', u'5342595028_C']

# %%
# Full-text search where matching a study results in all samples matching
query_text = "Door"  # partial for "Doorn"
result = es.search(index='cbit', doc_type='sample', body={
        "size": 100,
        "query": {
            "bool": {
                # A "bool" query with a "should" clause but no "must" clause is
                # ES's quirky way of expressing 'A or B'
                "should": [
                    { "match_phrase": { "_all": query_text } },
                    { "has_parent": {
                        "type": "study",
                        "query": { "match_phrase": { "_all": query_text } }
                    }}
                ]
            }
        },
        "aggs": {
            "studies": {
                "terms": {
                    "field": "_parent"
                }
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
p(result['aggregations'])
# Out:
# 18
# [u'5342595019_D', u'5342595019_E', u'5342595019_F', u'5342595019_G', u'5342595019_A', u'5342595019_B', u'5342595019_C', u'5342595019_H', u'5342595019_I', u'5342595028_H', u'5342595028_I', u'5342595028_D', u'5342595028_E', u'5342595028_F', u'5342595028_G', u'5342595028_A', u'5342595028_B', u'5342595028_C']
# {
#   "studies": {
#     "buckets": [
#       {
#         "doc_count": 18,
#         "key": "AVhDnx1kcZts01DBflFT"
#       }
#     ],
#     "doc_count_error_upper_bound": 0,
#     "sum_other_doc_count": 0
#   }
# }

# %%
# Full-text search where matching a study results in all samples matching
query_text = "strom"  # partial for "stromal cell"
result = es.search(index='cbit', doc_type='sample', body={
        "size": 100,
        "query": {
            "bool": {
                # A "bool" query with a "should" clause but no "must" clause is
                # ES's quirky way of expressing 'A or B'
                "should": [
                    { "match_phrase": { "_all": query_text } },
                    { "has_parent": {
                        "type": "study",
                        "query": { "match_phrase": { "_all": query_text } }
                    }}
                ]
            }
        },
        "aggs": {
            "studies": {
                "terms": {
                    "field": "_parent"
                }
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
p(result['aggregations'])
# Out:
# 27
# [u'5937337021_E', u'5937337059_E', u'5937337021_B', u'5937337021_L', u'5937337044_J', u'5937337044_A', u'5937337021_G', u'5937337059_G', u'5937337061_D', u'5342595019_D', u'5342595019_G', u'5342595019_A', u'5342595028_D', u'5342595028_G', u'5342595028_A', u'5342595019_E', u'5342595019_F', u'5342595019_B', u'5342595019_C', u'5342595019_H', u'5342595019_I', u'5342595028_H', u'5342595028_I', u'5342595028_E', u'5342595028_F', u'5342595028_B', u'5342595028_C']
# {
#   "studies": {
#     "buckets": [
#       {
#         "doc_count": 18,
#         "key": "AVhDnx1kcZts01DBflFT"
#       },
#       {
#         "doc_count": 9,
#         "key": "AVhDnyLlcZts01DBflFU"
#       }
#     ],
#     "doc_count_error_upper_bound": 0,
#     "sum_other_doc_count": 0
#   }
# }

# %% [markdown]
# ---
#
# Awesome!  Full-text search now works!  Now for filtering
#
# ---

# %%
# Full-text search where matching a study results in all samples matching
query_text = "strom"  # partial for "stromal cell"
result = es.search(index='cbit', doc_type='sample', body={
        "size": 100,
        "query": {
            "bool": {
                # A "bool" query with a "should" clause but no "must" clause is
                # ES's quirky way of expressing 'A or B'
                "should": [
                    { "match_phrase": { "_all": query_text } },
                    { "has_parent": {
                        "type": "study",
                        "query": { "match_phrase": { "_all": query_text } }
                    }}
                ],
                "must_not": [
                    { "term": { "*Compound": "8-br-cAMP - 8-bromo-cAMP" }}
                ]
            }
        },
        "aggs": {
            "studies": {
                "terms": {
                    "field": "_parent"
                }
            }
        },
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
p(result['aggregations'])
# Out:
# 21
# [u'5937337021_E', u'5937337059_E', u'5937337021_B', u'5937337021_L', u'5937337044_J', u'5937337044_A', u'5937337021_G', u'5937337059_G', u'5937337061_D', u'5342595019_D', u'5342595019_G', u'5342595019_A', u'5342595028_D', u'5342595028_G', u'5342595028_A', u'5342595019_E', u'5342595019_B', u'5342595019_H', u'5342595028_H', u'5342595028_E', u'5342595028_B']
# {
#   "studies": {
#     "buckets": [
#       {
#         "doc_count": 12,
#         "key": "AVhDnx1kcZts01DBflFT"
#       },
#       {
#         "doc_count": 9,
#         "key": "AVhDnyLlcZts01DBflFU"
#       }
#     ],
#     "doc_count_error_upper_bound": 0,
#     "sum_other_doc_count": 0
#   }
# }

# %% [markdown]
# ---
#
# AWESOME!  This is going to work...
#
# Let's go for aggregations.  We need to apply either all the sample metadata exclusion filters,
# or all but those related to a particular field (to have proper counts in the sidebar)
#
# ---

# %%
# Full-text search where matching a study results in all samples matching
# but with a compound excluded
#
# (In the real app, make sizes of `terms` aggregation large enough to not matter too much, but
#  degrade gracefully by ordering by document count in the query, then resorting
#  alphabetically client-side.  That way, the filters will show values alphabetically, but
#  only for the most common filters.  Should show a warning if there's truncation)
#
query_text = "strom"  # partial for "stromal cell"
all_metadata_exclusions = [
    { "term": { "*Compound": "8-br-cAMP - 8-bromo-cAMP" }}
]
all_but_compound_metadata_exclusions = [
]
result = es.search(index='cbit', doc_type='sample', body={
        "size": 100,
        "query": {
            "bool": {
                # A "bool" query with a "should" clause but no "must" clause is
                # ES's quirky way of expressing 'A or B'
                "should": [
                    { "match_phrase": { "_all": query_text } },
                    { "has_parent": {
                        "type": "study",
                        "query": { "match_phrase": { "_all": query_text } }
                    }}
                ]
            }
        },
        "aggs": {
            "all_filters": {
                "filter": {"bool": {"must_not": all_metadata_exclusions}},
                "aggs": {
                    "studies": {
                        "terms": {
                            "field": "_parent",
                            "size": 100   # Return 100 top studies
                        }
                    },
                    "Array or chip design": {
                        "terms": {
                            "field": "Array or chip design",
                            "missing": "<None>",
                            "size": 100,   # Return first 100 field values
                            "order": { "_term": "asc" }
                        }
                    },
                    "Attach Duration (hours)": {
                        "terms": {
                            "field": "Attach Duration (hours)",
                            "missing": "<None>",
                            "size": 100,   # Return first 100 field values
                            "order": { "_term": "asc" }
                        }
                    },
                    "*Material": {
                        "terms": {
                            "field": "*Material",
                            "missing": "<None>",
                            "size": 100,   # Return first 100 field values
                            "order": { "_term": "asc" }
                        }
                    },
                }
            },
            "all_but_compound_filters": {
                "filter": {"bool": {"must_not": all_but_compound_metadata_exclusions}},
                "aggs": {
                    "*Compound": {
                        "terms": {
                            "field": "*Compound",
                            "missing": "<None>",
                            "size": 100,   # Return first 100 field values
                            "order": { "_term": "asc" }
                        }
                    }
                }
            }
        },
        "post_filter": {"bool": {"must_not": all_metadata_exclusions}},
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
p(result['aggregations'], None)
# Out:
# 21
# [u'5937337021_E', u'5937337059_E', u'5937337021_B', u'5937337021_L', u'5937337044_J', u'5937337044_A', u'5937337021_G', u'5937337059_G', u'5937337061_D', u'5342595019_D', u'5342595019_G', u'5342595019_A', u'5342595028_D', u'5342595028_G', u'5342595028_A', u'5342595019_E', u'5342595019_B', u'5342595019_H', u'5342595028_H', u'5342595028_E', u'5342595028_B']
# {
#   "all_but_compound_filters": {
#     "*Compound": {
#       "buckets": [
#         {
#           "doc_count": 6,
#           "key": "8-br-cAMP - 8-bromo-cAMP"
#         },
#         {
#           "doc_count": 15,
#           "key": "<None>"
#         },
#         {
#           "doc_count": 6,
#           "key": "db-cAMP - dibutyryl-cAMP"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     },
#     "doc_count": 27
#   },
#   "all_filters": {
#     "*Material": {
#       "buckets": [
#         {
#           "doc_count": 3,
#           "key": "BCP - biphasic calcium phosphate"
#         },
#         {
#           "doc_count": 3,
#           "key": "HA - hydroxyapatite"
#         },
#         {
#           "doc_count": 12,
#           "key": "PS - polystyrene"
#         },
#         {
#           "doc_count": 3,
#           "key": "TCP - tricalcium phosphate"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     },
#     "Array or chip design": {
#       "buckets": [
#         {
#           "doc_count": 12,
#           "key": "Illumina HT12v3"
#         },
#         {
#           "doc_count": 9,
#           "key": "Illumina HT12v4"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     },
#     "Attach Duration (hours)": {
#       "buckets": [
#         {
#           "doc_count": 12,
#           "key": "12.5"
#         },
#         {
#           "doc_count": 9,
#           "key": "4.0"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     },
#     "doc_count": 21,
#     "studies": {
#       "buckets": [
#         {
#           "doc_count": 12,
#           "key": "AVhDnx1kcZts01DBflFT"
#         },
#         {
#           "doc_count": 9,
#           "key": "AVhDnyLlcZts01DBflFU"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     }
#   }
# }

# %%
# If we need to add controls back in, need to issue two queries: one to get matching
# control sample IDs, then the second is the real query
# Full-text search where matching a study results in all samples matching
# but with a compound excluded
#
# (In the real app, make sizes of `terms` aggregation large enough to not matter too much, but
#  degrade gracefully by ordering by document count in the query, then resorting
#  alphabetically client-side.  That way, the filters will show values alphabetically, but
#  only for the most common filters.  Should show a warning if there's truncation)
#
query_text = "db-cam"  # partial for "db-camp".  there's 6 samples matching & 6 controls
all_metadata_exclusions = [
    { "term": { "*Compound": "8-br-cAMP - 8-bromo-cAMP" }}
]
all_but_compound_metadata_exclusions = [
]

controls_result = es.search(index='cbit', doc_type='sample', body={
        "size": 100,
        "query": {
            "bool": {
                # A "bool" query with a "should" clause but no "must" clause is
                # ES's quirky way of expressing 'A or B'
                'must': { "exists": { "field": "Sample Match" }},
                "should": [
                    { "match_phrase": { "_all": query_text } },
                    { "has_parent": {
                        "type": "study",
                        "query": { "match_phrase": { "_all": query_text } }
                    }}
                ],
                "must_not": all_metadata_exclusions
            }
        },
        "_source": ['Sample Match']
    })

controls = [sample['_source']['Sample Match'] for sample in controls_result['hits']['hits']]

result = es.search(index='cbit', doc_type='sample', body={
        "size": 100,
        "query": {
            "bool": {
                # A "bool" query with a "should" clause but no "must" clause is
                # ES's quirky way of expressing 'A or B'
                "should": [
                    { "match_phrase": { "_all": query_text } },
                    { "has_parent": {
                        "type": "study",
                        "query": { "match_phrase": { "_all": query_text } }
                    }},
                    { "terms": { "Sample Name": controls } }
                ]
            }
        },
        "aggs": {
            "all_filters": {
                "filter": {"bool": {"must_not": all_metadata_exclusions}},
                "aggs": {
                    "studies": {
                        "terms": {
                            "field": "_parent",
                            "size": 100   # Return 100 top studies
                        }
                    },
                    "Array or chip design": {
                        "terms": {
                            "field": "Array or chip design",
                            "missing": "<None>",
                            "size": 100,   # Return first 100 field values
                            "order": { "_term": "asc" }
                        }
                    },
                    "Attach Duration (hours)": {
                        "terms": {
                            "field": "Attach Duration (hours)",
                            "missing": "<None>",
                            "size": 100,   # Return first 100 field values
                            "order": { "_term": "asc" }
                        }
                    },
                    "*Material": {
                        "terms": {
                            "field": "*Material",
                            "missing": "<None>",
                            "size": 100,   # Return first 100 field values
                            "order": { "_term": "asc" }
                        }
                    },
                }
            },
            "all_but_compound_filters": {
                "filter": {"bool": {"must_not": all_but_compound_metadata_exclusions}},
                "aggs": {
                    "*Compound": {
                        "terms": {
                            "field": "*Compound",
                            "missing": "<None>",
                            "size": 100,   # Return first 100 field values
                            "order": { "_term": "asc" }
                        }
                    }
                }
            }
        },
        "post_filter": {"bool": {"must_not": all_metadata_exclusions}},
        "_source": ['STUDY.Study Title', 'STUDY.Study Researchers Involved',
                    'Sample Name', '*Study ID']
    })
print(result['hits']['total'])
print([hit['_source'].get('Sample Name', hit['_source'].get('STUDY', {}).get('Study Title', '?'))
       for hit in result['hits']['hits']])
p(result['aggregations'], None)
# Out:
# 12
# [u'5342595019_E', u'5342595019_B', u'5342595019_H', u'5342595028_H', u'5342595028_E', u'5342595028_B', u'5342595019_D', u'5342595019_G', u'5342595019_A', u'5342595028_D', u'5342595028_G', u'5342595028_A']
# {
#   "all_but_compound_filters": {
#     "*Compound": {
#       "buckets": [
#         {
#           "doc_count": 6,
#           "key": "<None>"
#         },
#         {
#           "doc_count": 6,
#           "key": "db-cAMP - dibutyryl-cAMP"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     },
#     "doc_count": 12
#   },
#   "all_filters": {
#     "*Material": {
#       "buckets": [
#         {
#           "doc_count": 12,
#           "key": "PS - polystyrene"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     },
#     "Array or chip design": {
#       "buckets": [
#         {
#           "doc_count": 12,
#           "key": "Illumina HT12v3"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     },
#     "Attach Duration (hours)": {
#       "buckets": [
#         {
#           "doc_count": 12,
#           "key": "12.5"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     },
#     "doc_count": 12,
#     "studies": {
#       "buckets": [
#         {
#           "doc_count": 12,
#           "key": "AVhDnx1kcZts01DBflFT"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     }
#   }
# }

# %%
# Look up controls using an aggregation, to avoid bringing back duplicates over the wire
query_text = "db-cam"  # partial for "db-camp".  there's 6 samples matching & 6 controls
all_metadata_exclusions = [
    { "term": { "*Compound": "8-br-cAMP - 8-bromo-cAMP" }}
]
all_but_compound_metadata_exclusions = [
]

controls_result = es.search(index='cbit', doc_type='sample', body={
        "size": 0,
        "query": {
            "bool": {
                # A "bool" query with a "should" clause but no "must" clause is
                # ES's quirky way of expressing 'A or B'
                'must': { "exists": { "field": "Sample Match" }},
                "should": [
                    { "match_phrase": { "_all": query_text } },
                    { "has_parent": {
                        "type": "study",
                        "query": { "match_phrase": { "_all": query_text } }
                    }}
                ],
                "must_not": all_metadata_exclusions
            }
        },
        "aggs": {
            "controls": {
                "terms": {
                    "field": "Sample Match",
                    "size": 10000
                }
            }
        }
    })

p(controls_result, None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "aggregations": {
#     "controls": {
#       "buckets": [
#         {
#           "doc_count": 1,
#           "key": "5342595019_A"
#         },
#         {
#           "doc_count": 1,
#           "key": "5342595019_D"
#         },
#         {
#           "doc_count": 1,
#           "key": "5342595019_G"
#         },
#         {
#           "doc_count": 1,
#           "key": "5342595028_A"
#         },
#         {
#           "doc_count": 1,
#           "key": "5342595028_D"
#         },
#         {
#           "doc_count": 1,
#           "key": "5342595028_G"
#         }
#       ],
#       "doc_count_error_upper_bound": 0,
#       "sum_other_doc_count": 0
#     }
#   },
#   "hits": {
#     "hits": [],
#     "max_score": 0.0,
#     "total": 6
#   },
#   "timed_out": false,
#   "took": 8
# }

# %% [markdown]
# ---
#
# AWESOME!  I can do absolutely everything I need in two queries.  It seems there's also a plug-in to implement [filter joins](https://github.com/sirensolutions/siren-join) to do the lookup of relevant controls in the same query.  So with that, I could by with exactly 1 query.  I'll put that down to Sprint 3

# %%
# Get the study metadata and all associated sample metadata for a single study
es.search(index='cbit', body={
        "size": 100,
        "query": {
            "bool": {
                "should": [
                    {
                        "bool": {
                            "must": [
                                { "match": { "_type": "study" } },
                                { "match": { "_id": study1_id } },
                            ]
                        }
                    },
                    {
                        "bool": {
                            "must": [
                                { "match": { "_type": "sample" } },
                                {
                                    "has_parent": {
                                        "type": "study",
                                        "query": { "match": { "_id": study1_id } }
                                    }
                                }
                            ]
                        }
                    }
                ]
            }
        }
    })
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'hits': {u'hits': [{u'_id': u'AVhDnx1kcZts01DBflFT',
#     u'_index': u'cbit',
#     u'_score': 0.5,
#     u'_source': {u'INVESTIGATION': {u'Investigation Identifier': u'1478015927860',
#       u'Investigation Title': u'Investigation'},
#      u'ONTOLOGY SOURCE REFERENCE': {u'Term Source Description': u'Experimental Factor Ontology',
#       u'Term Source File': u'http://data.bioontology.org/ontologies/EFO',
#       u'Term Source Name': u'EFO',
#       u'Term Source Version': u'149'},
#      u'STUDY': {u'Study Description': u'Osteogenic differentiation of human mesenchymal stromal cells (hMSCs) may potentially be used in cell-based bone tissue-engineering applications to enhance the bone-forming potential of these cells. Osteogenic differentiation and adipogenic differentiation are thought to be mutually exclusive, and although several signaling pathways and cues that induce osteogenic or adipogenic differentiation, respectively, have been identified, there is no general consensus on how to optimally differentiate hMSCs into the osteogenic lineage. Some pathways have also been reported to be involved in both adipogenic and osteogenic differentiation, as for example, the protein kinase A (PKA) pathway, and the aim of this study was to investigate the role of cAMP/PKA signaling in differentiation of hMSCs in more detail. We show that activation of this pathway with dibutyryl-cAMP results in enhanced alkaline phosphatase expression, whereas another cAMP analog induces adipogenesis in long-term mineralization cultures. Adipogenic differentiation, induced by 8-bromo-cAMP, was accompanied by stronger PKA activity and higher expression of cAMP-responsive genes, suggesting that stronger activation correlates with adipogenic differentiation. In addition, a whole-genome expression analysis showed an increase in expression of adipogenic genes in 8-br-cAMP-treated cells. Furthermore, by means of quantitative polymerase chain reaction, we show differences in peroxisome proliferator-activated receptor-gamma activation, either alone or in combination with dexamethasone, thus demonstrating differential effects of the PKA pathway, most likely depending on its mode of activation.',
#       u'Study File Name': u's_study_sample.txt',
#       u'Study Identifier': u'StudyID_01',
#       u'Study Public Release Date': u'2012-05-30',
#       u'Study Researchers Involved': u'Doorn J, Leusink M, Groen N, van de Peppel J, van Leeuwen JP, van Blitterswijk CA, de Boer J',
#       u'Study Submission Date': u'2011-08-25',
#       u'Study Title': u'Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells'},
#      u'STUDY ASSAYS': {u'Study Assay File Name': u'a_transcription_micro_1.txt',
#       u'Study Assay Measurement Type': u'transcription profiling',
#       u'Study Assay Technology Platform': u'Illumina',
#       u'Study Assay Technology Type': u'DNA microarray'},
#      u'STUDY CONTACTS': [{u'Study Person Affiliation': u'Maastricht University',
#        u'Study Person First Name': u'Jan',
#        u'Study Person Last Name': u'de Boer'},
#       {u'Study Person Affiliation': u'Maastricht University',
#        u'Study Person First Name': u'Dennie',
#        u'Study Person Last Name': u'Hebels'}],
#      u'STUDY DESIGN DESCRIPTORS': {u'Study Design Type': u'compound treatment design'},
#      u'STUDY FACTORS': [{u'Study Factor Name': u'Age',
#        u'Study Factor Type': u'Age'},
#       {u'Study Factor Name': u'Attach Duration',
#        u'Study Factor Type': u'Attach Duration'},
#       {u'Study Factor Name': u'Compound', u'Study Factor Type': u'Compound'},
#       {u'Study Factor Name': u'Dose', u'Study Factor Type': u'Dose'},
#       {u'Study Factor Name': u'Dose Duration',
#        u'Study Factor Type': u'Dose Duration'},
#       {u'Study Factor Name': u'Dose Frequency',
#        u'Study Factor Type': u'Dose Frequency'},
#       {u'Study Factor Name': u'Culture Duration',
#        u'Study Factor Type': u'Culture Duration'},
#       {u'Study Factor Name': u'Material abbreviation',
#        u'Study Factor Type': u'Material abbreviation'},
#       {u'Study Factor Name': u'Sintering temperature',
#        u'Study Factor Type': u'Sintering temperature'}],
#      u'STUDY PROTOCOLS': [{u'Study Protocol Description': u'Bone marrow aspirates were obtained from donors after obtaining written informed consent. hMSCs were isolated and proliferated as described previously. Briefly, aspirates were resuspended using 20G needles, plated at a density of 5.105 cells/cm2, and cultured in an hMSC proliferation medium, consisting of an alpha-minimal essential medium (alpha-MEM; Life Technologies), 10% fetal bovine serum (FBS; Cambrex Bio sciences, Verviers), 0.2 mM ascorbic acid 2-phosphate (ASAP; Sigma Aldrich), 2 mM L-glutamine (Invitrogen, Life Technologies), 100 U/mL penicillin (Life Technologies), 10 ug/mL streptomycin (Life Technologies), and 1 ng/mL basic fibroblast growth factor (bFGF; Instruchemie). Cells were grown at 37\xb0C, in a humid atmosphere with 5% CO2. The medium was refreshed twice a week, and cells were used for further subculturing or cryopreservation upon reaching near confluence. The hMSC basic medium was composed of a proliferation medium without bFGF.\nFor whole-genome expression analysis, hMSCs were seeded in 12-well plates at 5000 cells/cm2 and allowed to attach for 10\u201315 h in a proliferation medium. The next day, either a basic medium or a basic medium supplemented with 1 mM db-cAMP or 8-br-cAMP was added. After 6 or 72 h of treatment, cells were lyzed directly from the plate, and RNA was isolated.',
#        u'Study Protocol Name': u'Protocol_01_Sample_treatment',
#        u'Study Protocol Type': u'Protocol_01_Sample_treatment'},
#       {u'Study Protocol Description': u'In this study no materials were synthesized. All cells were grown on standard 12-well polystyrene plates.',
#        u'Study Protocol Name': u'Protocol_02_Material_synthesis',
#        u'Study Protocol Type': u'Protocol_02_Material_synthesis'},
#       {u'Study Protocol Description': u'After 6 or 72 h of treatment, cells were lyzed directly from the plate. RNA was isolated using a Bioke RNA II nucleospin RNA isolation kit (Machery Nagel), and RNA concentrations were measured using an ND100 spectrophotometer (Nanodrop technologies).',
#        u'Study Protocol Name': u'Protocol_03_RNA_extraction',
#        u'Study Protocol Type': u'Protocol_03_RNA_extraction'},
#       {u'Study Protocol Description': u"From 500 ng of RNA, cRNA was synthesized using the Illumina TotalPrep RNA amplification Kit (Ambion/Life Technologies), according to the manufacturer's protocol, and RNA and cRNA quality was verified on Bioanalyzer 2100 (Agilent).",
#        u'Study Protocol Name': u'Protocol_04_Labeling',
#        u'Study Protocol Type': u'Protocol_04_Labeling'},
#       {u'Study Protocol Description': u"Microarrays were performed using Illumina HT-12 v3 expression Beadchips (Illumina), according to the manufacturer's protocol. Briefly, 750 ng of cRNA was hybridized on the array overnight, after which the array was washed and blocked. Then, by addition of streptavidin Cy-3 (Illumina), a fluorescent signal was developed.",
#        u'Study Protocol Name': u'Protocol_05_Nucleic_acid_hybridization',
#        u'Study Protocol Parameters Name': u'Hybridization Date',
#        u'Study Protocol Type': u'Protocol_05_Nucleic_acid_hybridization'},
#       {u'Study Protocol Description': u'Arrays were scanned on an Illumina iScan, and raw intensity values were background corrected in Genomestudio (Illumina). Further data processing and statistical testing were performed using R and Bioconductor statistical software (www.bioconductor.org/).',
#        u'Study Protocol Name': u'Protocol_06_Data_collection',
#        u'Study Protocol Type': u'Protocol_06_Data_collection'},
#       {u'Study Protocol Description': u'The probe-level raw intensity values were quantile normalized.',
#        u'Study Protocol Name': u'Protocol_07_Normalization_data_transformation',
#        u'Study Protocol Parameters Name': u'Background correction',
#        u'Study Protocol Type': u'Protocol_07_Normalization_data_transformation'},
#       {u'Study Protocol Description': u'The normalized intensity values were transformed using variance stabilization.',
#        u'Study Protocol Name': u'Protocol_08_Data transformation',
#        u'Study Protocol Type': u'Protocol_08_Data transformation'}],
#      u'STUDY PUBLICATIONS': [{u'Study PubMed ID': u'22646480',
#        u'Study Publication Author List': u'Doorn J, Leusink M, Groen N, van de Peppel J, van Leeuwen JP, van Blitterswijk CA, de Boer J',
#        u'Study Publication DOI': u'10.1089/ten.TEA.2011.0484',
#        u'Study Publication Status': u'published',
#        u'Study Publication Status Term Accession Number': u'http://www.ebi.ac.uk/efo/EFO_0001796',
#        u'Study Publication Status Term Source REF': u'EFO',
#        u'Study Publication Title': u'Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells'}]},
#     u'_type': u'study'},
#    {u'_id': u'AVhDn2IicZts01DBflFV',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595019_D',
#      u'Biological Replicate': 2,
#      u'Biologically degradable': u'no',
#      u'Cell type': u'stromal cell',
#      u'Control': True,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 0.0,
#      u'Dose Duration (hours)': 6.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 1,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-1-2',
#      u'Sample Name': u'5342595019_D',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IicZts01DBflFW',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'db-cAMP - dibutyryl-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595019_E',
#      u'Biological Replicate': 2,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'362-74-3',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'dibutyryl-cAMP',
#      u'Compound abbreviation': u'db-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 6.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 2,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-2-2',
#      u'Sample Match': u'5342595019_D',
#      u'Sample Name': u'5342595019_E',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IicZts01DBflFX',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'8-br-cAMP - 8-bromo-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595019_F',
#      u'Biological Replicate': 2,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'23583-48-4',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'8-bromo-cAMP',
#      u'Compound abbreviation': u'8-br-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 6.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 3,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-3-2',
#      u'Sample Match': u'5342595019_D',
#      u'Sample Name': u'5342595019_F',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IicZts01DBflFY',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595019_G',
#      u'Biological Replicate': 3,
#      u'Biologically degradable': u'no',
#      u'Cell type': u'stromal cell',
#      u'Control': True,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 0.0,
#      u'Dose Duration (hours)': 6.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 1,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-1-3',
#      u'Sample Name': u'5342595019_G',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IicZts01DBflFZ',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595019_A',
#      u'Biological Replicate': 1,
#      u'Biologically degradable': u'no',
#      u'Cell type': u'stromal cell',
#      u'Control': True,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 0.0,
#      u'Dose Duration (hours)': 6.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 1,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-1-1',
#      u'Sample Name': u'5342595019_A',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IicZts01DBflFa',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'db-cAMP - dibutyryl-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595019_B',
#      u'Biological Replicate': 1,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'362-74-3',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'dibutyryl-cAMP',
#      u'Compound abbreviation': u'db-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 6.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 2,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-2-1',
#      u'Sample Match': u'5342595019_A',
#      u'Sample Name': u'5342595019_B',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IicZts01DBflFb',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'8-br-cAMP - 8-bromo-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595019_C',
#      u'Biological Replicate': 1,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'23583-48-4',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'8-bromo-cAMP',
#      u'Compound abbreviation': u'8-br-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 6.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 3,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-3-1',
#      u'Sample Match': u'5342595019_A',
#      u'Sample Name': u'5342595019_C',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IicZts01DBflFc',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'db-cAMP - dibutyryl-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595019_H',
#      u'Biological Replicate': 3,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'362-74-3',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'dibutyryl-cAMP',
#      u'Compound abbreviation': u'db-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 6.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 2,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-2-3',
#      u'Sample Match': u'5342595019_G',
#      u'Sample Name': u'5342595019_H',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFd',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'8-br-cAMP - 8-bromo-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595019_I',
#      u'Biological Replicate': 3,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'23583-48-4',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'8-bromo-cAMP',
#      u'Compound abbreviation': u'8-br-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 6.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 3,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-3-3',
#      u'Sample Match': u'5342595019_G',
#      u'Sample Name': u'5342595019_I',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFe',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'db-cAMP - dibutyryl-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595028_H',
#      u'Biological Replicate': 3,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'362-74-3',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'dibutyryl-cAMP',
#      u'Compound abbreviation': u'db-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 72.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 5,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-5-3',
#      u'Sample Match': u'5342595028_G',
#      u'Sample Name': u'5342595028_H',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFf',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'8-br-cAMP - 8-bromo-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595028_I',
#      u'Biological Replicate': 3,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'23583-48-4',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'8-bromo-cAMP',
#      u'Compound abbreviation': u'8-br-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 72.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 6,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-6-3',
#      u'Sample Match': u'5342595028_G',
#      u'Sample Name': u'5342595028_I',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFg',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595028_D',
#      u'Biological Replicate': 2,
#      u'Biologically degradable': u'no',
#      u'Cell type': u'stromal cell',
#      u'Control': True,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 0.0,
#      u'Dose Duration (hours)': 72.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 4,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-4-2',
#      u'Sample Name': u'5342595028_D',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFh',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'db-cAMP - dibutyryl-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595028_E',
#      u'Biological Replicate': 2,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'362-74-3',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'dibutyryl-cAMP',
#      u'Compound abbreviation': u'db-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 72.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 5,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-5-2',
#      u'Sample Match': u'5342595028_D',
#      u'Sample Name': u'5342595028_E',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFi',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'8-br-cAMP - 8-bromo-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595028_F',
#      u'Biological Replicate': 2,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'23583-48-4',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'8-bromo-cAMP',
#      u'Compound abbreviation': u'8-br-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 72.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 6,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-6-2',
#      u'Sample Match': u'5342595028_D',
#      u'Sample Name': u'5342595028_F',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFj',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595028_G',
#      u'Biological Replicate': 3,
#      u'Biologically degradable': u'no',
#      u'Cell type': u'stromal cell',
#      u'Control': True,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 0.0,
#      u'Dose Duration (hours)': 72.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 4,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-4-3',
#      u'Sample Name': u'5342595028_G',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFk',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595028_A',
#      u'Biological Replicate': 1,
#      u'Biologically degradable': u'no',
#      u'Cell type': u'stromal cell',
#      u'Control': True,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 0.0,
#      u'Dose Duration (hours)': 72.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 4,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-4-1',
#      u'Sample Name': u'5342595028_A',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFl',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'db-cAMP - dibutyryl-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595028_B',
#      u'Biological Replicate': 1,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'362-74-3',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'dibutyryl-cAMP',
#      u'Compound abbreviation': u'db-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 72.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 5,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-5-1',
#      u'Sample Match': u'5342595028_A',
#      u'Sample Name': u'5342595028_B',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'},
#    {u'_id': u'AVhDn2IjcZts01DBflFm',
#     u'_index': u'cbit',
#     u'_parent': u'AVhDnx1kcZts01DBflFT',
#     u'_routing': u'AVhDnx1kcZts01DBflFT',
#     u'_score': 0.5,
#     u'_source': {u'*Compound': u'8-br-cAMP - 8-bromo-cAMP',
#      u'*Material': u'PS - polystyrene',
#      u'*Strain': u'hMSC - human mesenchymal stromal cells',
#      u'Array or chip design': u'Illumina HT12v3',
#      u'Assay Type': u'in vitro',
#      u'Attach Duration (hours)': 12.5,
#      u'Barcode': u'5342595028_C',
#      u'Biological Replicate': 1,
#      u'Biologically degradable': u'no',
#      u'CAS number': u'23583-48-4',
#      u'Cell type': u'stromal cell',
#      u'Compound': u'8-bromo-cAMP',
#      u'Compound abbreviation': u'8-br-cAMP',
#      u'Control': False,
#      u'Culture medium': u'alpha-MEM',
#      u'Dose (mM)': 1.0,
#      u'Dose Duration (hours)': 72.0,
#      u'Gene expression type': u'Microarray',
#      u'Group ID': 6,
#      u'Material Class': u'polymer',
#      u'Material Name': u'polystyrene',
#      u'Material Shape': u'flat',
#      u'Material abbreviation': u'PS',
#      u'Organ': u'bone',
#      u'Organism': u'Homo sapiens',
#      u'Passage number': 2,
#      u'Platform': u'Illumina',
#      u'Protocols': u'Protocol_01_Sample_treatment, Protocol_02_Material_synthesis',
#      u'Sample ID': u'01-6-1',
#      u'Sample Match': u'5342595028_A',
#      u'Sample Name': u'5342595028_C',
#      u'Sex': u'unknown',
#      u'Source Name': 1,
#      u'Strain abbreviation': u'hMSC',
#      u'Strain full name': u'human mesenchymal stromal cells',
#      u'Study ID': 1,
#      u'Tissue': u'connective',
#      u'Transcriptomics Assay Detail: Background correction': u'yes',
#      u'Transcriptomics Assay Detail: Data Transformation Name': u'variance stabilization',
#      u'Transcriptomics Assay Detail: Label': u'biotin',
#      u'Transcriptomics Assay Detail: Normalization Name': u'quantile'},
#     u'_type': u'sample'}],
#   u'max_score': 0.5,
#   u'total': 19},
#  u'timed_out': False,
#  u'took': 6}

# %%
# Get sample mappings (for generating list of applicable filters)
p(es.indices.get_mapping(index='cbit', doc_type='sample'), None)
# Out:
# {
#   "cbit": {
#     "mappings": {
#       "sample": {
#         "_all": {
#           "analyzer": "autocomplete",
#           "search_analyzer": "standard"
#         },
#         "_parent": {
#           "type": "study"
#         },
#         "_routing": {
#           "required": true
#         },
#         "dynamic": "true",
#         "dynamic_templates": [
#           {
#             "default": {
#               "mapping": {
#                 "include_in_all": true,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "match": "*"
#             }
#           }
#         ],
#         "properties": {
#           "*Compound": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "*Material": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "*Phase composition - % HA": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "*Phase composition - % TCP": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "*Strain": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Array or chip design": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Assay Type": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Attach Duration (hours)": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Barcode": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Biological Replicate": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Biologically degradable": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "CAS number": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Cell type": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Compound": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Compound abbreviation": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Control": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Culture Duration (hours)": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Culture medium": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Dose (mM)": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Dose Duration (hours)": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Gene expression type": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Group ID": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Manufacturer": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Material Class": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Material Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Material Shape": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Material abbreviation": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Organ": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Organism": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Passage number": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Phase composition": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Phase composition device": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Platform": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Protocols": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sample ID": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sample Match": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sample Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sex": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sintering temperature": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Source Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Strain abbreviation": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Strain full name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Study ID": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Tissue": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Transcriptomics Assay Detail: Background correction": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Transcriptomics Assay Detail: Data Transformation Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Transcriptomics Assay Detail: Label": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Transcriptomics Assay Detail: Normalization Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           }
#         }
#       }
#     }
#   }
# }

# %%
print(study1_id)
print(study2_id)
# Out:
# AVhDnx1kcZts01DBflFT
# AVhDnyLlcZts01DBflFU

# %%
es.search(index='cbit', doc_type='sample', body={
    "query": {
      "bool": {
        "must": {
          "exists": {
            "field": "Control"
          }
        }
      }
    },
    "size": 100,
    "_source": ["Control"],
    "aggs": {
      "studies": {
        "terms": {
          "field": "_parent",
          "size": 10000
        }
      }
    }
  }
)
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'aggregations': {u'studies': {u'buckets': [{u'doc_count': 54,
#      u'key': u'AVhJhnMu8X1My4__bYgF'},
#     {u'doc_count': 18, u'key': u'AVhJhfxO8X1My4__bYgD'}],
#    u'doc_count_error_upper_bound': 0,
#    u'sum_other_doc_count': 0}},
#  u'hits': {u'hits': [{u'_id': u'AVhJhwUC8X1My4__bYgG',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': True},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgH',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgI',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgJ',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': True},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgK',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': True},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgL',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgM',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgN',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgO',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgP',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgQ',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgR',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': True},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgS',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgT',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgU',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': True},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgV',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': True},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgW',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgX',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhfxO8X1My4__bYgD',
#     u'_routing': u'AVhJhfxO8X1My4__bYgD',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgY',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgZ',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYga',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgb',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgc',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgd',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYge',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgf',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgg',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgh',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgi',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgj',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgk',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgl',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgm',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgn',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUC8X1My4__bYgo',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgp',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgq',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgr',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgs',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgt',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgu',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgv',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgw',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgx',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgy',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYgz',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg0',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg1',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg2',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg3',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg4',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg5',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg6',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg7',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg8',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg9',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg-',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYg_',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhA',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhB',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhC',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhD',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhE',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhF',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhG',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhH',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhI',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhJ',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhK',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhL',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhM',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'},
#    {u'_id': u'AVhJhwUD8X1My4__bYhN',
#     u'_index': u'cbit',
#     u'_parent': u'AVhJhnMu8X1My4__bYgF',
#     u'_routing': u'AVhJhnMu8X1My4__bYgF',
#     u'_score': 1.0,
#     u'_source': {u'Control': False},
#     u'_type': u'sample'}],
#   u'max_score': 1.0,
#   u'total': 72},
#  u'timed_out': False,
#  u'took': 15}

# %%
p(es.indices.get_mapping(index='cbit', doc_type='sample'), None)
# Out:
# {
#   "cbit": {
#     "mappings": {
#       "sample": {
#         "_all": {
#           "analyzer": "autocomplete",
#           "search_analyzer": "standard"
#         },
#         "_parent": {
#           "type": "study"
#         },
#         "_routing": {
#           "required": true
#         },
#         "dynamic": "true",
#         "dynamic_templates": [
#           {
#             "default": {
#               "mapping": {
#                 "include_in_all": true,
#                 "index": "not_analyzed",
#                 "type": "string"
#               },
#               "match": "*"
#             }
#           }
#         ],
#         "properties": {
#           "*Compound": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "*Material": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "*Phase composition - % HA": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "*Phase composition - % TCP": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "*Strain": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Array or chip design": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Assay Type": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Attach Duration (hours)": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Barcode": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Biological Replicate": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Biologically degradable": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "CAS number": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Cell type": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Compound": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Compound abbreviation": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Control": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Culture Duration (hours)": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Culture medium": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Dose (mM)": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Dose Duration (hours)": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Gene expression type": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Group ID": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Manufacturer": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Material Class": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Material Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Material Shape": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Material abbreviation": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Organ": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Organism": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Passage number": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Phase composition": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Phase composition device": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Platform": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Protocols": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sample ID": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sample Match": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sample Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sex": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Sintering temperature": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Source Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Strain abbreviation": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Strain full name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Study ID": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Tissue": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Transcriptomics Assay Detail: Background correction": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Transcriptomics Assay Detail: Data Transformation Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Transcriptomics Assay Detail: Label": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           },
#           "Transcriptomics Assay Detail: Normalization Name": {
#             "include_in_all": true,
#             "index": "not_analyzed",
#             "type": "string"
#           }
#         }
#       }
#     }
#   }
# }

# %%
es.search(index='cbit', doc_type='sample', body={
        'size': 0,
        'aggs': {
            'controls': {
                'terms': {
                    'field': 'Control'
                }
            }
        }
    })
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'aggregations': {u'controls': {u'buckets': [{u'doc_count': 66,
#      u'key': u'false'},
#     {u'doc_count': 6, u'key': u'true'}],
#    u'doc_count_error_upper_bound': 0,
#    u'sum_other_doc_count': 0}},
#  u'hits': {u'hits': [], u'max_score': 0.0, u'total': 72},
#  u'timed_out': False,
#  u'took': 3}

# %%
es.search(index='cbit', doc_type='sample', body={
    "size": 10,
    "query": {
      "bool": {
        "should": [
          {
            "match_phrase": {
              "_all": "23632322"
            }
          }
                    #,
          #{
          #  "has_parent": {
          #    "type": "study",
          #    "query": {
          #      "match_phrase": {
          #        "_all": "23632322"
          #      }
          #    }
          #  }
          #}
        ],
        "must": [
          {
            "exists": {
              "field": "Sample Match"
            }
          }
        ],
        "must_not": [],
                "minimum_should_match": 1
      }
    },
    "aggs": {
      "controls": {
        "terms": {
          "field": "Sample Match",
          "size": 10000
        }
      }
    }
  })
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'aggregations': {u'controls': {u'buckets': [],
#    u'doc_count_error_upper_bound': 0,
#    u'sum_other_doc_count': 0}},
#  u'hits': {u'hits': [], u'max_score': None, u'total': 0},
#  u'timed_out': False,
#  u'took': 1}

# %% [markdown]
# # Enumerating all possible values of all properties

# %% [markdown]
# I'd like to fetch a stable list of all possible properties and all their possible values

# %%
sample_mapping = es.indices.get_mapping(index='cbit', doc_type='sample')
properties = sample_mapping['cbit']['mappings']['sample']['properties']
print("***** FROM MAPPING *****")
p(properties)
print("************************")
print("")

aggs_to_query = {
    propName: {
        "terms": {
            "field": propName,
            "missing": "<None>",
            "size": 10000,
            "order": { "_term": "asc" }
        }
    }
    
    for propName in properties
}
result = es.search(index='cbit', doc_type='sample', body={
        "size": 0,
        "aggs": aggs_to_query
    })
print("***** RAW RESULTS *****")
p(result['aggregations'], 100)
print("***********************")

processed_results = {
    propName: {
        bucketEntry['key']: bucketEntry['doc_count']
        for bucketEntry in propAgg['buckets']
    }
    for propName, propAgg in result['aggregations'].iteritems()
}
print("***** PROCESSED RESULTS *****")
p(processed_results)
print("*****************************")
# Out:
# ***** FROM MAPPING *****
# {
#   "*Compound": {
#     "include_in_all": true,
#     "index": "not_analyzed",
#     "type": "string"
#   },
#   "*Elements composition - % Ca": {
#     "include_in_all": true,
#     "index": "not_analyzed",
#     "type": "string"
#   },
#   "*Elements composition - % F": {
# ...
#     "type": "string"
#   },
#   "Weight loss (% / week)": {
#     "include_in_all": true,
#     "index": "not_analyzed",
#     "type": "string"
#   },
#   "Wettability": {
#     "include_in_all": true,
#     "index": "not_analyzed",
#     "type": "string"
#   }
# }
# ************************
#
# ***** RAW RESULTS *****
# {
#   "*Compound": {
#     "buckets": [
#       {
#         "doc_count": 6,
#         "key": "8-br-cAMP - 8-bromo-cAMP"
#       },
#       {
#         "doc_count": 123,
#         "key": "<None>"
#       },
#       {
#         "doc_count": 6,
#         "key": "db-cAMP - dibutyryl-cAMP"
#       }
#     ],
#     "doc_count_error_upper_bound": 0,
#     "sum_other_doc_count": 0
#   },
#   "*Elements composition - % Ca": {
#     "buckets": [
#       {
#         "doc_count": 12,
#         "key": "1000.0"
#       },
#       {
#         "doc_count": 3,
#         "key": "1225.0"
#       },
#       {
#         "doc_count": 3,
#         "key": "1250.0"
#       },
#       {
#         "doc_count": 12,
#         "key": "1900.0"
#       },
#       {
#         "doc_count": 105,
#         "key": "<None>"
#       }
#     ],
#     "doc_count_error_upper_bound": 0,
#     "sum_other_doc_count": 0
#   },
#   "*Elements composition - % F": {
#     "buckets": [
#       {
#         "doc_count": 3,
#         "key": "2500.0"
# ...
#         "doc_count": 108,
#         "key": "<None>"
#       }
#     ],
#     "doc_count_error_upper_bound": 0,
#     "sum_other_doc_count": 0
#   },
#   "Wettability": {
#     "buckets": [
#       {
#         "doc_count": 81,
#         "key": "<None>"
#       },
#       {
#         "doc_count": 6,
#         "key": "water=40;ethanol=52;PBS=37;HBSS=37"
#       },
#       {
#         "doc_count": 3,
#         "key": "water=43;ethanol=57;PBS=48"
#       },
#       {
#         "doc_count": 3,
#         "key": "water=43;ethanol=58;PBS=47"
#       },
#       {
#         "doc_count": 6,
#         "key": "water=44;ethanol=42;PBS=48"
#       },
#       {
#         "doc_count": 12,
#         "key": "water=44;ethanol=63"
#       },
#       {
#         "doc_count": 6,
#         "key": "water=45.6;ethanol=42.3;PBS=48.2"
#       },
#       {
#         "doc_count": 6,
#         "key": "water=45;ethanol=40;PBS=46"
#       },
#       {
#         "doc_count": 12,
#         "key": "water=45;ethanol=60"
#       }
#     ],
#     "doc_count_error_upper_bound": 0,
#     "sum_other_doc_count": 0
#   }
# }
# ***********************
# ***** PROCESSED RESULTS *****
# {
#   "*Compound": {
#     "8-br-cAMP - 8-bromo-cAMP": 6,
#     "<None>": 123,
#     "db-cAMP - dibutyryl-cAMP": 6
#   },
#   "*Elements composition - % Ca": {
#     "1000.0": 12,
#     "1225.0": 3,
#     "1250.0": 3,
#     "1900.0": 12,
#     "<None>": 105
# ...
#   },
#   "Wettability": {
#     "<None>": 81,
#     "water=40;ethanol=52;PBS=37;HBSS=37": 6,
#     "water=43;ethanol=57;PBS=48": 3,
#     "water=43;ethanol=58;PBS=47": 3,
#     "water=44;ethanol=42;PBS=48": 6,
#     "water=44;ethanol=63": 12,
#     "water=45.6;ethanol=42.3;PBS=48.2": 6,
#     "water=45;ethanol=40;PBS=46": 6,
#     "water=45;ethanol=60": 12
#   }
# }
# *****************************

# %%
es.search(index='cbit', doc_type='sample', body={
        "aggs": {
    "Filtered *Material": {
      "aggs": {
        "*Material": {
          "terms": {
            "field": "*Material",
            "missing": "<None>",
            "order": {
              "_term": "asc"
            },
            "size": 100
          }
        }
      },
      "filter": {
        "bool": {
          "should": [
            {
              "terms": {
                "Sample Name": []
              }
            },
            {
              "bool": {
                "must": {},
                "must_not": {}
              }
            }
          ]
        }
      }
    },
    "all_filters": {
      "aggs": {
        "Manufacturer": {
          "terms": {
            "field": "Manufacturer",
            "missing": "<None>",
            "order": {
              "_term": "asc"
            },
            "size": 100
          }
        }
      },
      "filter": {
        "bool": {
          "should": [
            {
              "terms": {
                "Sample Name": []
              }
            },
            {
              "bool": {
                "must": [
                  {
                    "terms": {
                      "*Material": []
                    }
                  }
                ],
                "must_not": []
              }
            }
          ]
        }
      }
    }
  },
  "query": {
    "bool": {
      "should": [
        {
          "match_phrase": {
            "_all": "db-camp"
          }
        },
        {
          "has_parent": {
            "query": {
              "match_phrase": {
                "_all": "db-camp"
              }
            },
            "type": "study"
          }
        }
      ]
    }
  },
  "size": 0
    })
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'aggregations': {u'Filtered *Material': {u'*Material': {u'buckets': [{u'doc_count': 6,
#       u'key': u'PS - polystyrene'}],
#     u'doc_count_error_upper_bound': 0,
#     u'sum_other_doc_count': 0},
#    u'doc_count': 6},
#   u'all_filters': {u'Manufacturer': {u'buckets': [],
#     u'doc_count_error_upper_bound': 0,
#     u'sum_other_doc_count': 0},
#    u'doc_count': 0}},
#  u'hits': {u'hits': [], u'max_score': 0.0, u'total': 6},
#  u'timed_out': False,
#  u'took': 7}

# %%
studyIds = ['a84395b0-fd6b-47ff-8ac3-bdb97a25d684', 'e9c44d82-8d5d-447b-a322-9767cf43330a']
rawResults = es.search(index='cbit', doc_type='study', body={
            "size": len(studyIds),
            "query": {
                "ids": {
                    "values": studyIds
                }
            }
        })
p(rawResults, None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_index": "cbit",
#         "_score": 1.0,
#         "_source": {
#           "*Archive URL": "http://localhost:23456/studies/e9c44d82-8d5d-447b-a322-9767cf43330a/archive",
#           "INVESTIGATION": {
#             "Investigation Identifier": "1478018798109",
#             "Investigation Title": "Investigation"
#           },
#           "ONTOLOGY SOURCE REFERENCE": {
#             "Term Source Description": "Experimental Factor Ontology",
#             "Term Source File": "http://data.bioontology.org/ontologies/EFO",
#             "Term Source Name": "EFO",
#             "Term Source Version": "149"
#           },
#           "STUDY": {
#             "Study Description": "Biomaterial properties can be tailored for specific applications via systematic and high-throughput screening of biomaterial\u2013cell interactions. However, progress in material development is often hampered by the lack of adequate in vitro testing methods, frequently due to incomplete understanding of involved in vivo mechanisms. In line with drug discovery in pharmacology, a crucial step in assay development for biomaterial screening is the identification of a target to direct the screen against. Herein, the cell type to be used for screening is of essential importance and has to be carefully chosen. So far, few attention has been put on selecting a cell type specifically suitable for in vitro testing of materials for predefined applications. In this manuscript, we describe an approach to define a suitable cell type for screening assays, for which biomaterials for bone regeneration served as example. Using a bioinformatics methodology, different cell lines are compared on three well-characterized model materials. The transcriptional profiles of MG63, iMSC, SV-HFO, hPPCT, hBPCT and SW480 cells are assessed on 3 calcium phosphate-based materials to evaluate their potential application in a screening assay. We show that MG63 is the most suitable cell line to evaluate biomaterials for bone regeneration applications, evidenced by their robust gene expression differences between the 3 model materials. The gene expression differences between the cell lines were assessed based on the overall gene expression profiles and specific subsets of genes and pathways related to osteogenesis and bone homeostasis in response to the 3 materials tested. In the next phase, this cell line will be used to identify a target correlating with in vivo biomaterial performance and henceforth to develop an in vitro screening system.",
#             "Study File Name": "s_study_sample.txt",
#             "Study Identifier": "StudyID_02",
#             "Study Public Release Date": "2013-04-28",
#             "Study Researchers Involved": "Groen N, van de Peppel J, Yuan H, van Leeuwen JP, van Blitterswijk CA, de Boer J",
#             "Study Submission Date": "2013-03-12",
#             "Study Title": "Bioinformatics-based selection of a model cell type for in vitro biomaterial testing"
#           },
#           "STUDY ASSAYS": {
#             "Study Assay File Name": "a_transcription_micro_1.txt",
#             "Study Assay Measurement Type": "transcription profiling",
#             "Study Assay Technology Platform": "Illumina",
#             "Study Assay Technology Type": "DNA microarray"
#           },
#           "STUDY CONTACTS": [
#             {
#               "Study Person Affiliation": "Maastricht University",
#               "Study Person First Name": "Jan",
#               "Study Person Last Name": "de Boer"
#             },
#             {
#               "Study Person Affiliation": "Maastricht University",
#               "Study Person First Name": "Dennie",
#               "Study Person Last Name": "Hebels"
#             }
#           ],
#           "STUDY DESIGN DESCRIPTORS": {
#             "Study Design Type": "material testing design"
#           },
#           "STUDY FACTORS": [
#             {
#               "Study Factor Name": "Age",
#               "Study Factor Type": "Age"
#             },
#             {
#               "Study Factor Name": "Attach Duration",
#               "Study Factor Type": "Attach Duration"
#             },
#             {
#               "Study Factor Name": "Compound",
#               "Study Factor Type": "Compound"
#             },
#             {
#               "Study Factor Name": "Dose",
#               "Study Factor Type": "Dose"
#             },
#             {
#               "Study Factor Name": "Dose Duration",
#               "Study Factor Type": "Dose Duration"
#             },
#             {
#               "Study Factor Name": "Dose Frequency",
#               "Study Factor Type": "Dose Frequency"
#             },
#             {
#               "Study Factor Name": "Culture Duration",
#               "Study Factor Type": "Culture Duration"
#             },
#             {
#               "Study Factor Name": "Material abbreviation",
#               "Study Factor Type": "Material abbreviation"
#             },
#             {
#               "Study Factor Name": "Sintering temperature",
#               "Study Factor Type": "Sintering temperature"
#             }
#           ],
#           "STUDY PROTOCOLS": [
#             {
#               "Study Protocol Description": "A colorectal adenocarcinoma derived epithelial cell line (SW480, ATCC; kindly provided by Prof. H. Clevers), a peripheral nerve derived pericyte cell line (hPPCT) and a blood-brain barrier derived pericyte cell line (hBPCT, both kindly provided by Prof. T. Kanda) [35] were cultured in basic medium composed of Dulbecco's modified Eagle's medium (DMEM, Life Technologies), 10% fetal bovine serum (FBS, Lonza), 100 U/mL penicillin (Life Technologies) and 100 g/mL streptomycin (Life Technologies). Both pericyte cell lines were expanded on collagen type I coated 100 mm plates (BD BioCoat\u2122) at 33 \u00b0C. The osteosarcoma cell line MG63 (ATCC) and immortalized mesenchymal stromal cell line (iMSC, kindly provided by Dr. O. Myklebost (Oslo University Hospital, Norway)) were expanded in basic medium containing alpha-minimal essential medium (alpha-MEM, Life Technologies), 10% fetal bovine serum, 0.2 mm ascorbic acid (Asap, Life Technologies), 2 mm l-glutamine (Life Technologies), 100 U/mL penicillin, 100 ug/ml streptomycin. A human pre-osteoblastic cell line (SV-HFO; [36] and [37]) was cultured in basic medium containing phenol-free alpha-MEM (Life Technologies), 10% FBS, 100 U/mL penicillin, 100 ug/ml streptomycin, 20 mm HEPES and pH-adjusted to 7.5. Medium was refreshed twice a week and cells were used for experiments, further sub-culturing or cryopreservation upon reaching near confluence. Further experiments were performed at 37 \u00b0C and 5% CO2 for each cell type. \nTo characterize the cell-material constructs, 200,000 cells were seeded per standard volume of 150 uL of pre-wetted material in 100 uL basic medium and allowed to attach for 4 h before adding additional medium. However, for iMSC, initial seeding number was increased to 300,000 in order to obtain sufficient RNA to perform the microarray study. The cell-material constructs were cultured in their respective basic medium (without any additives) for 48 h, after which cross sections were made to evaluate the cell distribution throughout the material.",
#               "Study Protocol Name": "Protocol_01_Sample_treatment",
#               "Study Protocol Type": "Protocol_01_Sample_treatment"
#             },
#             {
#               "Study Protocol Description": "Hydroxyapatite (HA) ceramics were prepared from HA powder (Merck) using the dual-phase mixing method and sintered at 1250 \u00b0C for 8 h according to a previously described method [39]. Biphasic calcium phosphate (BCP) ceramics were fabricated using the H2O2 method using in-house-made calcium-deficient apatite powder and sintered at 1150 \u00b0C (BCP) [17]. The method used to synthesize the BCP ceramics was also used for preparation of tricalcium phosphate (TCP). TCP ceramics were prepared from TCP powder (Plasma Biotal) and sintered at 1100 \u00b0C. Ceramic particles (1\u20132 mm) were prepared, cleaned ultrasonically with acetone, 70% ethanol and demineralized water, dried at 80 \u00b0C, and sterilized by gamma irradiation prior to use.",
#               "Study Protocol Name": "Protocol_02_Material_synthesis",
#               "Study Protocol Type": "Protocol_02_Material_synthesis"
#             },
#             {
#               "Study Protocol Description": "After 48 h, total RNA was isolated from each cell type cultured on the materials using TRIzol (Invitrogen) and the Nucleospin RNA isolation kit (Macherey\u2013Nagel) according to the manufacturer's protocol.",
#               "Study Protocol Name": "Protocol_03_RNA_extraction",
#               "Study Protocol Type": "Protocol_03_RNA_extraction"
#             },
#             {
#               "Study Protocol Description": "From 350 ng of RNA, cRNA was synthesized using the Illumina TotalPrep RNA amplification Kit, according to the manufacturer's protocol and both RNA and cRNA quality were verified on a Bioanalyzer 2100 (Agilent).",
#               "Study Protocol Name": "Protocol_04_Labeling",
#               "Study Protocol Type": "Protocol_04_Labeling"
#             },
#             {
#               "Study Protocol Description": "Microarrays were performed using Illumina HT-12 v4 expression Beadchips, according to the manufacturer's protocol. Briefly, 750 ng of cRNA was hybridized on the array overnight after which the array was washed and blocked. Then, by addition of streptavidin Cy-3 a fluorescent signal was developed.",
#               "Study Protocol Name": "Protocol_05_Nucleic_acid_hybridization",
#               "Study Protocol Parameters Name": "Hybridization Date",
#               "Study Protocol Type": "Protocol_05_Nucleic_acid_hybridization"
#             },
#             {
#               "Study Protocol Description": "Arrays were scanned on an Illumina Beadarray reader and raw intensity values were background corrected in BeadStudio (Illumina).",
#               "Study Protocol Name": "Protocol_06_Data_collection",
#               "Study Protocol Type": "Protocol_06_Data_collection"
#             },
#             {
#               "Study Protocol Description": "The probe-level raw intensity values were quantile normalized.",
#               "Study Protocol Name": "Protocol_07_Normalization_data_transformation",
#               "Study Protocol Parameters Name": "Background correction",
#               "Study Protocol Type": "Protocol_07_Normalization_data_transformation"
#             },
#             {
#               "Study Protocol Description": "The normalized probe-level intensity values were transformed using variance stabilization (VSN).",
#               "Study Protocol Name": "Protocol_08_Data transformation",
#               "Study Protocol Type": "Protocol_08_Data transformation"
#             }
#           ],
#           "STUDY PUBLICATIONS": [
#             {
#               "Study PubMed ID": "23632322",
#               "Study Publication Author List": "Groen N, van de Peppel J, Yuan H, van Leeuwen JP, van Blitterswijk CA, de Boer J",
#               "Study Publication DOI": "10.1016/j.biomaterials.2013.04.001",
#               "Study Publication Status": "published",
#               "Study Publication Status Term Accession Number": "http://www.ebi.ac.uk/efo/EFO_0001796",
#               "Study Publication Status Term Source REF": "EFO",
#               "Study Publication Title": "Bioinformatics-based selection of a model cell type for in vitro biomaterial testing"
#             }
#           ]
#         },
#         "_type": "study"
#       },
#       {
#         "_id": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_index": "cbit",
#         "_score": 1.0,
#         "_source": {
#           "*Archive URL": "http://localhost:23456/studies/a84395b0-fd6b-47ff-8ac3-bdb97a25d684/archive",
#           "INVESTIGATION": {
#             "Investigation Identifier": "1478015927860",
#             "Investigation Title": "Investigation"
#           },
#           "ONTOLOGY SOURCE REFERENCE": {
#             "Term Source Description": "Experimental Factor Ontology",
#             "Term Source File": "http://data.bioontology.org/ontologies/EFO",
#             "Term Source Name": "EFO",
#             "Term Source Version": "149"
#           },
#           "STUDY": {
#             "Study Description": "Osteogenic differentiation of human mesenchymal stromal cells (hMSCs) may potentially be used in cell-based bone tissue-engineering applications to enhance the bone-forming potential of these cells. Osteogenic differentiation and adipogenic differentiation are thought to be mutually exclusive, and although several signaling pathways and cues that induce osteogenic or adipogenic differentiation, respectively, have been identified, there is no general consensus on how to optimally differentiate hMSCs into the osteogenic lineage. Some pathways have also been reported to be involved in both adipogenic and osteogenic differentiation, as for example, the protein kinase A (PKA) pathway, and the aim of this study was to investigate the role of cAMP/PKA signaling in differentiation of hMSCs in more detail. We show that activation of this pathway with dibutyryl-cAMP results in enhanced alkaline phosphatase expression, whereas another cAMP analog induces adipogenesis in long-term mineralization cultures. Adipogenic differentiation, induced by 8-bromo-cAMP, was accompanied by stronger PKA activity and higher expression of cAMP-responsive genes, suggesting that stronger activation correlates with adipogenic differentiation. In addition, a whole-genome expression analysis showed an increase in expression of adipogenic genes in 8-br-cAMP-treated cells. Furthermore, by means of quantitative polymerase chain reaction, we show differences in peroxisome proliferator-activated receptor-gamma activation, either alone or in combination with dexamethasone, thus demonstrating differential effects of the PKA pathway, most likely depending on its mode of activation.",
#             "Study File Name": "s_study_sample.txt",
#             "Study Identifier": "StudyID_01",
#             "Study Public Release Date": "2012-05-30",
#             "Study Researchers Involved": "Doorn J, Leusink M, Groen N, van de Peppel J, van Leeuwen JP, van Blitterswijk CA, de Boer J",
#             "Study Submission Date": "2011-08-25",
#             "Study Title": "Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells"
#           },
#           "STUDY ASSAYS": {
#             "Study Assay File Name": "a_transcription_micro_1.txt",
#             "Study Assay Measurement Type": "transcription profiling",
#             "Study Assay Technology Platform": "Illumina",
#             "Study Assay Technology Type": "DNA microarray"
#           },
#           "STUDY CONTACTS": [
#             {
#               "Study Person Affiliation": "Maastricht University",
#               "Study Person First Name": "Jan",
#               "Study Person Last Name": "de Boer"
#             },
#             {
#               "Study Person Affiliation": "Maastricht University",
#               "Study Person First Name": "Dennie",
#               "Study Person Last Name": "Hebels"
#             }
#           ],
#           "STUDY DESIGN DESCRIPTORS": {
#             "Study Design Type": "compound treatment design"
#           },
#           "STUDY FACTORS": [
#             {
#               "Study Factor Name": "Age",
#               "Study Factor Type": "Age"
#             },
#             {
#               "Study Factor Name": "Attach Duration",
#               "Study Factor Type": "Attach Duration"
#             },
#             {
#               "Study Factor Name": "Compound",
#               "Study Factor Type": "Compound"
#             },
#             {
#               "Study Factor Name": "Dose",
#               "Study Factor Type": "Dose"
#             },
#             {
#               "Study Factor Name": "Dose Duration",
#               "Study Factor Type": "Dose Duration"
#             },
#             {
#               "Study Factor Name": "Dose Frequency",
#               "Study Factor Type": "Dose Frequency"
#             },
#             {
#               "Study Factor Name": "Culture Duration",
#               "Study Factor Type": "Culture Duration"
#             },
#             {
#               "Study Factor Name": "Material abbreviation",
#               "Study Factor Type": "Material abbreviation"
#             },
#             {
#               "Study Factor Name": "Sintering temperature",
#               "Study Factor Type": "Sintering temperature"
#             }
#           ],
#           "STUDY PROTOCOLS": [
#             {
#               "Study Protocol Description": "Bone marrow aspirates were obtained from donors after obtaining written informed consent. hMSCs were isolated and proliferated as described previously. Briefly, aspirates were resuspended using 20G needles, plated at a density of 5.105 cells/cm2, and cultured in an hMSC proliferation medium, consisting of an alpha-minimal essential medium (alpha-MEM; Life Technologies), 10% fetal bovine serum (FBS; Cambrex Bio sciences, Verviers), 0.2 mM ascorbic acid 2-phosphate (ASAP; Sigma Aldrich), 2 mM L-glutamine (Invitrogen, Life Technologies), 100 U/mL penicillin (Life Technologies), 10 ug/mL streptomycin (Life Technologies), and 1 ng/mL basic fibroblast growth factor (bFGF; Instruchemie). Cells were grown at 37\u00b0C, in a humid atmosphere with 5% CO2. The medium was refreshed twice a week, and cells were used for further subculturing or cryopreservation upon reaching near confluence. The hMSC basic medium was composed of a proliferation medium without bFGF.\nFor whole-genome expression analysis, hMSCs were seeded in 12-well plates at 5000 cells/cm2 and allowed to attach for 10\u201315 h in a proliferation medium. The next day, either a basic medium or a basic medium supplemented with 1 mM db-cAMP or 8-br-cAMP was added. After 6 or 72 h of treatment, cells were lyzed directly from the plate, and RNA was isolated.",
#               "Study Protocol Name": "Protocol_01_Sample_treatment",
#               "Study Protocol Type": "Protocol_01_Sample_treatment"
#             },
#             {
#               "Study Protocol Description": "In this study no materials were synthesized. All cells were grown on standard 12-well polystyrene plates.",
#               "Study Protocol Name": "Protocol_02_Material_synthesis",
#               "Study Protocol Type": "Protocol_02_Material_synthesis"
#             },
#             {
#               "Study Protocol Description": "After 6 or 72 h of treatment, cells were lyzed directly from the plate. RNA was isolated using a Bioke RNA II nucleospin RNA isolation kit (Machery Nagel), and RNA concentrations were measured using an ND100 spectrophotometer (Nanodrop technologies).",
#               "Study Protocol Name": "Protocol_03_RNA_extraction",
#               "Study Protocol Type": "Protocol_03_RNA_extraction"
#             },
#             {
#               "Study Protocol Description": "From 500 ng of RNA, cRNA was synthesized using the Illumina TotalPrep RNA amplification Kit (Ambion/Life Technologies), according to the manufacturer's protocol, and RNA and cRNA quality was verified on Bioanalyzer 2100 (Agilent).",
#               "Study Protocol Name": "Protocol_04_Labeling",
#               "Study Protocol Type": "Protocol_04_Labeling"
#             },
#             {
#               "Study Protocol Description": "Microarrays were performed using Illumina HT-12 v3 expression Beadchips (Illumina), according to the manufacturer's protocol. Briefly, 750 ng of cRNA was hybridized on the array overnight, after which the array was washed and blocked. Then, by addition of streptavidin Cy-3 (Illumina), a fluorescent signal was developed.",
#               "Study Protocol Name": "Protocol_05_Nucleic_acid_hybridization",
#               "Study Protocol Parameters Name": "Hybridization Date",
#               "Study Protocol Type": "Protocol_05_Nucleic_acid_hybridization"
#             },
#             {
#               "Study Protocol Description": "Arrays were scanned on an Illumina iScan, and raw intensity values were background corrected in Genomestudio (Illumina). Further data processing and statistical testing were performed using R and Bioconductor statistical software (www.bioconductor.org/).",
#               "Study Protocol Name": "Protocol_06_Data_collection",
#               "Study Protocol Type": "Protocol_06_Data_collection"
#             },
#             {
#               "Study Protocol Description": "The probe-level raw intensity values were quantile normalized.",
#               "Study Protocol Name": "Protocol_07_Normalization_data_transformation",
#               "Study Protocol Parameters Name": "Background correction",
#               "Study Protocol Type": "Protocol_07_Normalization_data_transformation"
#             },
#             {
#               "Study Protocol Description": "The normalized intensity values were transformed using variance stabilization.",
#               "Study Protocol Name": "Protocol_08_Data transformation",
#               "Study Protocol Type": "Protocol_08_Data transformation"
#             }
#           ],
#           "STUDY PUBLICATIONS": [
#             {
#               "Study PubMed ID": "22646480",
#               "Study Publication Author List": "Doorn J, Leusink M, Groen N, van de Peppel J, van Leeuwen JP, van Blitterswijk CA, de Boer J",
#               "Study Publication DOI": "10.1089/ten.TEA.2011.0484",
#               "Study Publication Status": "published",
#               "Study Publication Status Term Accession Number": "http://www.ebi.ac.uk/efo/EFO_0001796",
#               "Study Publication Status Term Source REF": "EFO",
#               "Study Publication Title": "Diverse effects of cyclic AMP variants on osteogenic and adipogenic differentiation of human mesenchymal stromal cells"
#             }
#           ]
#         },
#         "_type": "study"
#       }
#     ],
#     "max_score": 1.0,
#     "total": 2
#   },
#   "timed_out": false,
#   "took": 2
# }

# %%
es.search(index='cbit', doc_type='sample', _source=['_id'])
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'hits': {u'hits': [{u'_id': u'AViYE2g0DNmn6Iqb5tLY',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'},
#    {u'_id': u'AViYE2g0DNmn6Iqb5tLZ',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'},
#    {u'_id': u'AViYE2g0DNmn6Iqb5tLa',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'},
#    {u'_id': u'AViYE2g0DNmn6Iqb5tLb',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'},
#    {u'_id': u'AViYE2g0DNmn6Iqb5tLc',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'},
#    {u'_id': u'AViYE2g0DNmn6Iqb5tLd',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'},
#    {u'_id': u'AViYE2g0DNmn6Iqb5tLe',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'},
#    {u'_id': u'AViYE2g0DNmn6Iqb5tLf',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'},
#    {u'_id': u'AViYE2g0DNmn6Iqb5tLg',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'},
#    {u'_id': u'AViYE2g0DNmn6Iqb5tLh',
#     u'_index': u'cbit',
#     u'_parent': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_routing': u'e9c44d82-8d5d-447b-a322-9767cf43330a',
#     u'_score': 1.0,
#     u'_source': {},
#     u'_type': u'sample'}],
#   u'max_score': 1.0,
#   u'total': 135},
#  u'timed_out': False,
#  u'took': 5}

# %%
studyIds = ['a84395b0-fd6b-47ff-8ac3-bdb97a25d684', 'e9c44d82-8d5d-447b-a322-9767cf43330a']
rawResults = es.search(index='cbit', doc_type='sample', _source=["_id"], body={
            "size": 1000,
            "query": {
                "has_parent": {
                    "parent_type": "study",
                    "query": {
                        "ids": {
                            "values": studyIds
                        }
                    }
                }
            }
        })
p(rawResults, None)
# Out:
# {
#   "_shards": {
#     "failed": 0,
#     "successful": 5,
#     "total": 5
#   },
#   "hits": {
#     "hits": [
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLY",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLZ",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLa",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLb",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLc",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLd",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLe",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLf",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLg",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLh",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLi",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLj",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLk",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLl",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLm",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLn",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLo",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLp",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLq",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLr",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLs",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLt",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLu",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLv",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLw",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLx",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLy",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tLz",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL0",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL1",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL2",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL3",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL4",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL5",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL6",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL7",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL8",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL9",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL-",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tL_",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMA",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMB",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMC",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMD",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tME",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMF",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMG",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMH",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMI",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMJ",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMK",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tML",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMM",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYE2g0DNmn6Iqb5tMN",
#         "_index": "cbit",
#         "_parent": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_routing": "e9c44d82-8d5d-447b-a322-9767cf43330a",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLF",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLG",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLH",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLI",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLJ",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLK",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLL",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLM",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLN",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLO",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLP",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLQ",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLR",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLS",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmJDNmn6Iqb5tLT",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmKDNmn6Iqb5tLU",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmKDNmn6Iqb5tLV",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       },
#       {
#         "_id": "AViYDnmKDNmn6Iqb5tLW",
#         "_index": "cbit",
#         "_parent": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_routing": "a84395b0-fd6b-47ff-8ac3-bdb97a25d684",
#         "_score": 1.0,
#         "_source": {},
#         "_type": "sample"
#       }
#     ],
#     "max_score": 1.0,
#     "total": 72
#   },
#   "timed_out": false,
#   "took": 16
# }
